# %% [markdown]
# # Lecture 3

# %% [markdown]
# ## Optimization
#
# Optimization is choosing the best option from a set of possible options.
# We have already encountered problems where we tried to find the best
# possible option, such as in the minimax algorithm, and today we will
# learn about tools that we can use to solve an even broader range of
# problems.

# %% [markdown]
# ## Local Search
#
# Local search is a search algorithm that maintains a single node and
# searches by moving to a neighboring node. This type of algorithm is
# different from previous types of search that we saw. Whereas in maze
# solving, for example, we wanted to find the quickest way to the goal,
# local search is interested in finding the best answer to a question.
# Often, local search will bring to an answer that is not optimal but
# “good enough,” conserving computational power. Consider the following
# example of a local search problem: we have four houses in set locations.
# We want to build two hospitals, such that we minimize the distance from
# each house to a hospital. This problem can be visualized as follows:
#
# ![Houses and Hospitals](https://cs50.harvard.edu/ai/2020/notes/3/hospitals1.png)
#
# In this illustration, we are seeing a possible configuration of houses
# and hospitals. The distance between them is measured using Manhattan
# distance (number of moves up, down, and to the sides; discussed in more
# detail in lecture 0), and the sum of the distances from each house to
# the nearest hospital is 17. We call this the **cost**, because we try to
# minimize this distance. In this case, a state would be any one
# configuration of houses and hospitals.
#
# Abstracting this concept, we can represent each configuration of houses
# and hospitals as the state-space landscape below. Each of the bars in
# the picture represents a value of a state, which in our example would be
# the cost of a certain configuration of houses and hospitals.
#
# ![State-Space Landscape](https://cs50.harvard.edu/ai/2020/notes/3/statespace.png)
#
# Going off of this visualization, we can define a few important terms for
# the rest of our discussion:
#
# - An **Objective Function** is a function
#     that we use to maximize the value of the solution.
# - A **Cost Function** is a function that we
#     use to minimize the cost of the solution (this is the function that
#     we would use in our example with houses and hospitals. We want to
#     minimize the distance from houses to hospitals).
# - A **Current State** is the state that is
#     currently being considered by the function.
# - A **Neighbor State** is a state that the
#     current state can transition to. In the one-dimensional state-space
#     landscape above, a neighbor state is the state to either side of the
#     current state. In our example, a neighbor state could be the state
#     resulting from moving one of the hospitals to any direction by one
#     step. Neighbor states are usually similar to the current state, and,
#     therefore, their values are close to the value of the current state.
#
# Note that the way local search algorithms work is by considering one
# node in a current state, and then moving the node to one of the current
# state’s neighbors. This is unlike the minimax algorithm, for example,
# where every single state in the state space was considered recursively.

# %% [markdown]
# ## Hill Climbing
#
# Hill climbing is one type of a local search algorithm. In this
# algorithm, the neighbor states are compared to the current state, and if
# any of them is better, we change the current node from the current state
# to that neighbor state. What qualifies as better is defined by whether
# we use an objective function, preferring a higher value, or a decreasing
# function, preferring a lower value.
#
# A hill climbing algorithm will look the following way in pseudocode:
#
# function Hill-Climb(*problem*):
#
# - *current* = initial state of *problem*
# - repeat:
#   - *neighbor* = best valued neighbor of
#         *current*
#   - if *neighbor* not better than
#         *current*:
#     - return *current*
#   - *current* = *neighbor*

# %%
import random

# Define the positions of the houses
houses = [(1, 3), (2, 1), (4, 2), (5, 4)]

# Define a function to calculate the Manhattan distance between two points
def manhattan_distance(point1, point2):
    return abs(point1[0] - point2[0]) + abs(point1[1] - point2[1])

# Define a function to calculate the total cost (sum of distances from each house to the nearest hospital)
def calculate_cost(houses, hospitals):
    total_cost = 0
    for house in houses:
        total_cost += min(manhattan_distance(house, hospital) for hospital in hospitals)
    return total_cost

# Define a function to get neighboring states by moving hospitals one step in any direction
def get_neighbors(hospitals):
    neighbors = []
    directions = [(0, 1), (1, 0), (0, -1), (-1, 0)]  # Up, Right, Down, Left
    for i, (hx, hy) in enumerate(hospitals):
        for dx, dy in directions:
            new_hospitals = hospitals[:]
            new_hospitals[i] = (hx + dx, hy + dy)
            neighbors.append(new_hospitals)
    return neighbors

# Hill Climbing Algorithm
def hill_climbing(houses, initial_hospitals):
    current_hospitals = initial_hospitals
    current_cost = calculate_cost(houses, current_hospitals)
    iteration = 0
    
    while True:
        print(f"Iteration {iteration}:")
        print(f"Current Hospitals: {current_hospitals}, Cost: {current_cost}")
        
        neighbors = get_neighbors(current_hospitals)
        neighbor_costs = [calculate_cost(houses, neighbor) for neighbor in neighbors]
        
        for neighbor, cost in zip(neighbors, neighbor_costs):
            print(f"Neighbor Hospitals: {neighbor}, Cost: {cost}")
        
        best_neighbor_index = neighbor_costs.index(min(neighbor_costs))
        
        if neighbor_costs[best_neighbor_index] >= current_cost:
            print("No better neighbors found. Ending search.")
            break
        
        current_hospitals = neighbors[best_neighbor_index]
        current_cost = neighbor_costs[best_neighbor_index]
        iteration += 1
        print()
    
    return current_hospitals, current_cost

# Initial random placement of hospitals
initial_hospitals = [(random.randint(0, 5), random.randint(0, 5)) for _ in range(2)]

# Perform hill climbing to find the best hospital locations
best_hospitals, best_cost = hill_climbing(houses, initial_hospitals)

print(f"Initial Hospitals: {initial_hospitals}")
print(f"Best Hospitals: {best_hospitals}")
print(f"Total Cost: {best_cost}")
# Out:
# Iteration 0:
# Current Hospitals: [(3, 4), (0, 3)], Cost: 10
# Neighbor Hospitals: [(3, 5), (0, 3)], Cost: 12
# Neighbor Hospitals: [(4, 4), (0, 3)], Cost: 8
# Neighbor Hospitals: [(3, 3), (0, 3)], Cost: 9
# Neighbor Hospitals: [(2, 4), (0, 3)], Cost: 11
# Neighbor Hospitals: [(3, 4), (0, 4)], Cost: 11
# Neighbor Hospitals: [(3, 4), (1, 3)], Cost: 8
# Neighbor Hospitals: [(3, 4), (0, 2)], Cost: 10
# Neighbor Hospitals: [(3, 4), (-1, 3)], Cost: 11
#
# Iteration 1:
# Current Hospitals: [(4, 4), (0, 3)], Cost: 8
# Neighbor Hospitals: [(4, 5), (0, 3)], Cost: 10
# Neighbor Hospitals: [(5, 4), (0, 3)], Cost: 8
# Neighbor Hospitals: [(4, 3), (0, 3)], Cost: 8
# Neighbor Hospitals: [(3, 4), (0, 3)], Cost: 10
# Neighbor Hospitals: [(4, 4), (0, 4)], Cost: 10
# Neighbor Hospitals: [(4, 4), (1, 3)], Cost: 6
# Neighbor Hospitals: [(4, 4), (0, 2)], Cost: 8
# Neighbor Hospitals: [(4, 4), (-1, 3)], Cost: 10
#
# Iteration 2:
# Current Hospitals: [(4, 4), (1, 3)], Cost: 6
# Neighbor Hospitals: [(4, 5), (1, 3)], Cost: 8
# Neighbor Hospitals: [(5, 4), (1, 3)], Cost: 6
# Neighbor Hospitals: [(4, 3), (1, 3)], Cost: 6
# Neighbor Hospitals: [(3, 4), (1, 3)], Cost: 8
# Neighbor Hospitals: [(4, 4), (1, 4)], Cost: 8
# Neighbor Hospitals: [(4, 4), (2, 3)], Cost: 6
# Neighbor Hospitals: [(4, 4), (1, 2)], Cost: 6
# Neighbor Hospitals: [(4, 4), (0, 3)], Cost: 8
# No better neighbors found. Ending search.
# Initial Hospitals: [(3, 4), (0, 3)]
# Best Hospitals: [(4, 4), (1, 3)]
# Total Cost: 6

# %% [markdown]
# In this algorithm, we start with a current state. In some problems, we
# will know what the current state is, while, in others, we will have to
# start with selecting one randomly. Then, we repeat the following
# actions: we evaluate the neighbors, selecting the one with the best
# value. Then, we compare this neighbor’s value to the current state’s
# value. If the neighbor is better, we switch the current state to the
# neighbor state, and then repeat the process. The process ends when we
# compare the best neighbor to the current state, and the current state is
# better. Then, we return the current state.
#
# Using the hill climbing algorithm, we can start to improve the locations
# that we assigned to the hospitals in our example. After a few
# transitions, we get to the following state:
#
# ![Houses and Hospitals at Local Minimum](https://cs50.harvard.edu/ai/2020/notes/3/hospitals2.png)
#
# At this state, the cost is 11, which is an improvement over 17, the cost
# of the initial state. However, this is not the optimal state just yet.
# For example, moving the hospital on the left to be underneath the top
# left house would bring to a cost of 9, which is better than 11. However,
# this version of a hill climbing algorithm can’t get there, because all
# the neighbor states are at least as costly as the current state. In this
# sense, a hill climbing algorithm is short-sighted, often settling for
# solutions that are *better* than some others, but not necessarily the
# *best* of all possible solutions.

# %% [markdown]
# ### Local and Global Minima and Maxima
#
# As mentioned above, a hill climbing algorithm can get stuck in local
# maxima or minima. A *local* **maximum** (plural: maxima) is a state that
# has a higher value than its *neighboring states*. As opposed to that, a
# ***global* maximum** is a state that has the highest value of *all
# states* in the state-space.
#
# ![Maxima](https://cs50.harvard.edu/ai/2020/notes/3/maxima.png)
#
# In contrast, a *local* **minimum** (plural: minima) is a state that has
# a lower value than its *neighboring states*. As opposed to that, a
# *global* **minimum** is a state that has the lowest value of *all states* in the state-space.
#
# ![Minima](https://cs50.harvard.edu/ai/2020/notes/3/minima.png)
#
# The problem with hill climbing algorithms is that they may end up in
# local minima and maxima. Once the algorithm reaches a point whose
# neighbors are worse, for the function’s purpose, than the current state,
# the algorithm stops. Special types of local maxima and minima include
# the **flat local maximum/minimum**, where multiple states of equal value
# are adjacent, forming a plateau whose neighbors have a worse value, and
# the **shoulder**, where multiple states of equal value are adjacent and
# the neighbors of the plateau can be both better and worse. Starting from
# the middle of the plateau, the algorithm will not be able to advance in
# any direction.
#
# ![Flat Local Maximum/Minimum and Shoulder](https://cs50.harvard.edu/ai/2020/notes/3/flatshoulder.png)

# %% [markdown]
# ### Hill Climbing Variants
#
# Due to the limitations of Hill Climbing, multiple variants have been
# thought of to overcome the problem of being stuck in local minima and
# maxima. What all variations of the algorithm have in common is that, no
# matter the strategy, each one still has the potential of ending up in
# local minima and maxima and no means to continue optimizing. The
# algorithms below are phrased such that a higher value is better, but
# they also apply to cost functions, where the goal is to minimize cost.
#
# - **Steepest-ascent**: choose the
#     highest-valued neighbor. This is the standard variation that we
#     discussed above.
# - **Stochastic**: choose randomly from
#     higher-valued neighbors. Doing this, we choose to go to any
#     direction that improves over our value. This makes sense if, for
#     example, the highest-valued neighbor leads to a local maximum while
#     another neighbor leads to a global maximum.
# - **First-choice**: choose the first
#     higher-valued neighbor.
# - **Random-restart**: conduct hill climbing
#     multiple times. Each time, start from a random state. Compare the
#     maxima from every trial, and choose the highest amongst those.
# - **Local Beam Search**: chooses the *k*
#     highest-valued neighbors. This is unlike most local search
#     algorithms in that it uses multiple nodes for the search, and not
#     just one.
#
# Although local search algorithms don’t always give the best possible
# solution, they can often give a good enough solution in situations where
# considering every possible state is computationally infeasible.

# %% [markdown]
# ## Simulated Annealing
#
# Although we have seen variants that can improve hill climbing, they all
# share the same fault: once the algorithm reaches a local maximum, it
# stops running. Simulated annealing allows the algorithm to “dislodge”
# itself if it gets stuck in a local maximum.
#
# Annealing is the process of heating metal and allowing it to cool
# slowly, which serves to toughen the metal. This is used as a metaphor
# for the simulated annealing algorithm, which starts with a high
# temperature, being more likely to make random decisions, and, as the
# temperature decreases, it becomes less likely to make random decisions,
# becoming more “firm.” This mechanism allows the algorithm to change its
# state to a neighbor that’s worse than the current state, which is how it
# can escape from local maxima. The following is pseudocode for simulated
# annealing:
#
# function Simulated-Annealing(*problem*, *max*):
#
# - *current* = initial state of *problem*
# - for *t* = 1 to *max*:
#   - *T* = Temperature(*t*)
#   - *neighbor* = random neighbor of
#         *current*
#   - *ΔE* = how much better *neighbor* is
#         than *current*
#   - if *ΔE* \> 0:
#     - *current* = *neighbor*
#   - with probability e^(*ΔE/T*) set
#         *current* = *neighbor*
# - return *current*

# %%
import random
import math

# Define the positions of the houses
houses = [(1, 3), (2, 1), (4, 2), (5, 4)]

# Define a function to calculate the Manhattan distance between two points
def manhattan_distance(point1, point2):
    return abs(point1[0] - point2[0]) + abs(point1[1] - point2[1])

# Define a function to calculate the total cost (sum of distances from each house to the nearest hospital)
def calculate_cost(houses, hospitals):
    total_cost = 0
    for house in houses:
        total_cost += min(manhattan_distance(house, hospital) for hospital in hospitals)
    return total_cost

# Define a function to get a random neighbor state by moving hospitals one step in any direction
def get_random_neighbor(hospitals):
    directions = [(0, 1), (1, 0), (0, -1), (-1, 0)]  # Up, Right, Down, Left
    i = random.randint(0, len(hospitals) - 1)
    hx, hy = hospitals[i]
    dx, dy = random.choice(directions)
    new_hospitals = hospitals[:]
    new_hospitals[i] = (hx + dx, hy + dy)
    return new_hospitals

# Define the simulated annealing algorithm
def simulated_annealing(houses, initial_hospitals, max_iterations, initial_temperature, cooling_rate):
    current_hospitals = initial_hospitals
    current_cost = calculate_cost(houses, current_hospitals)
    best_hospitals = current_hospitals
    best_cost = current_cost
    
    for t in range(1, max_iterations + 1):
        temperature = initial_temperature / (1 + cooling_rate * t)
        neighbor_hospitals = get_random_neighbor(current_hospitals)
        neighbor_cost = calculate_cost(houses, neighbor_hospitals)
        delta_cost = neighbor_cost - current_cost
        
        if delta_cost < 0 or random.random() < math.exp(-delta_cost / temperature):
            current_hospitals = neighbor_hospitals
            current_cost = neighbor_cost
        
        if current_cost < best_cost:
            best_hospitals = current_hospitals
            best_cost = current_cost
        
        print(f"Iteration {t}: Temperature = {temperature:.4f}, Current Cost = {current_cost}, Best Cost = {best_cost}")
    
    return best_hospitals, best_cost

# Initial random placement of hospitals
initial_hospitals = [(random.randint(0, 5), random.randint(0, 5)) for _ in range(2)]

# Parameters for simulated annealing
max_iterations = 1000
initial_temperature = 100.0
cooling_rate = 0.01

# Perform simulated annealing to find the best hospital locations
best_hospitals, best_cost = simulated_annealing(houses, initial_hospitals, max_iterations, initial_temperature, cooling_rate)

print(f"Initial Hospitals: {initial_hospitals}")
print(f"Best Hospitals: {best_hospitals}")
print(f"Total Cost: {best_cost}")
# Out:
# Iteration 1: Temperature = 99.0099, Current Cost = 12, Best Cost = 12
# Iteration 2: Temperature = 98.0392, Current Cost = 10, Best Cost = 10
# Iteration 3: Temperature = 97.0874, Current Cost = 10, Best Cost = 10
# Iteration 4: Temperature = 96.1538, Current Cost = 10, Best Cost = 10
# Iteration 5: Temperature = 95.2381, Current Cost = 9, Best Cost = 9
# Iteration 6: Temperature = 94.3396, Current Cost = 8, Best Cost = 8
# Iteration 7: Temperature = 93.4579, Current Cost = 9, Best Cost = 8
# Iteration 8: Temperature = 92.5926, Current Cost = 10, Best Cost = 8
# Iteration 9: Temperature = 91.7431, Current Cost = 10, Best Cost = 8
# Iteration 10: Temperature = 90.9091, Current Cost = 10, Best Cost = 8
# Iteration 11: Temperature = 90.0901, Current Cost = 12, Best Cost = 8
# Iteration 12: Temperature = 89.2857, Current Cost = 12, Best Cost = 8
# Iteration 13: Temperature = 88.4956, Current Cost = 12, Best Cost = 8
# Iteration 14: Temperature = 87.7193, Current Cost = 10, Best Cost = 8
# Iteration 15: Temperature = 86.9565, Current Cost = 10, Best Cost = 8
# Iteration 16: Temperature = 86.2069, Current Cost = 10, Best Cost = 8
# Iteration 17: Temperature = 85.4701, Current Cost = 10, Best Cost = 8
# Iteration 18: Temperature = 84.7458, Current Cost = 10, Best Cost = 8
# Iteration 19: Temperature = 84.0336, Current Cost = 12, Best Cost = 8
# Iteration 20: Temperature = 83.3333, Current Cost = 14, Best Cost = 8
# Iteration 21: Temperature = 82.6446, Current Cost = 18, Best Cost = 8
# Iteration 22: Temperature = 81.9672, Current Cost = 22, Best Cost = 8
# Iteration 23: Temperature = 81.3008, Current Cost = 24, Best Cost = 8
# Iteration 24: Temperature = 80.6452, Current Cost = 26, Best Cost = 8
# Iteration 25: Temperature = 80.0000, Current Cost = 26, Best Cost = 8
# Iteration 26: Temperature = 79.3651, Current Cost = 28, Best Cost = 8
# Iteration 27: Temperature = 78.7402, Current Cost = 26, Best Cost = 8
# Iteration 28: Temperature = 78.1250, Current Cost = 24, Best Cost = 8
# Iteration 29: Temperature = 77.5194, Current Cost = 26, Best Cost = 8
# Iteration 30: Temperature = 76.9231, Current Cost = 24, Best Cost = 8
# Iteration 31: Temperature = 76.3359, Current Cost = 22, Best Cost = 8
# Iteration 32: Temperature = 75.7576, Current Cost = 24, Best Cost = 8
# Iteration 33: Temperature = 75.1880, Current Cost = 26, Best Cost = 8
# Iteration 34: Temperature = 74.6269, Current Cost = 24, Best Cost = 8
# Iteration 35: Temperature = 74.0741, Current Cost = 22, Best Cost = 8
# Iteration 36: Temperature = 73.5294, Current Cost = 24, Best Cost = 8
# Iteration 37: Temperature = 72.9927, Current Cost = 23, Best Cost = 8
# Iteration 38: Temperature = 72.4638, Current Cost = 26, Best Cost = 8
# Iteration 39: Temperature = 71.9424, Current Cost = 27, Best Cost = 8
# Iteration 40: Temperature = 71.4286, Current Cost = 30, Best Cost = 8
# Iteration 41: Temperature = 70.9220, Current Cost = 28, Best Cost = 8
# Iteration 42: Temperature = 70.4225, Current Cost = 26, Best Cost = 8
# Iteration 43: Temperature = 69.9301, Current Cost = 22, Best Cost = 8
# Iteration 44: Temperature = 69.4444, Current Cost = 22, Best Cost = 8
# Iteration 45: Temperature = 68.9655, Current Cost = 22, Best Cost = 8
# Iteration 46: Temperature = 68.4932, Current Cost = 22, Best Cost = 8
# Iteration 47: Temperature = 68.0272, Current Cost = 22, Best Cost = 8
# Iteration 48: Temperature = 67.5676, Current Cost = 22, Best Cost = 8
# Iteration 49: Temperature = 67.1141, Current Cost = 22, Best Cost = 8
# Iteration 50: Temperature = 66.6667, Current Cost = 22, Best Cost = 8
# Iteration 51: Temperature = 66.2252, Current Cost = 18, Best Cost = 8
# Iteration 52: Temperature = 65.7895, Current Cost = 22, Best Cost = 8
# Iteration 53: Temperature = 65.3595, Current Cost = 26, Best Cost = 8
# Iteration 54: Temperature = 64.9351, Current Cost = 26, Best Cost = 8
# Iteration 55: Temperature = 64.5161, Current Cost = 26, Best Cost = 8
# Iteration 56: Temperature = 64.1026, Current Cost = 26, Best Cost = 8
# Iteration 57: Temperature = 63.6943, Current Cost = 30, Best Cost = 8
# Iteration 58: Temperature = 63.2911, Current Cost = 30, Best Cost = 8
# Iteration 59: Temperature = 62.8931, Current Cost = 30, Best Cost = 8
# Iteration 60: Temperature = 62.5000, Current Cost = 34, Best Cost = 8
# Iteration 61: Temperature = 62.1118, Current Cost = 34, Best Cost = 8
# Iteration 62: Temperature = 61.7284, Current Cost = 34, Best Cost = 8
# Iteration 63: Temperature = 61.3497, Current Cost = 34, Best Cost = 8
# Iteration 64: Temperature = 60.9756, Current Cost = 34, Best Cost = 8
# Iteration 65: Temperature = 60.6061, Current Cost = 30, Best Cost = 8
# Iteration 66: Temperature = 60.2410, Current Cost = 34, Best Cost = 8
# Iteration 67: Temperature = 59.8802, Current Cost = 30, Best Cost = 8
# Iteration 68: Temperature = 59.5238, Current Cost = 30, Best Cost = 8
# Iteration 69: Temperature = 59.1716, Current Cost = 30, Best Cost = 8
# Iteration 70: Temperature = 58.8235, Current Cost = 26, Best Cost = 8
# Iteration 71: Temperature = 58.4795, Current Cost = 26, Best Cost = 8
# Iteration 72: Temperature = 58.1395, Current Cost = 26, Best Cost = 8
# Iteration 73: Temperature = 57.8035, Current Cost = 26, Best Cost = 8
# Iteration 74: Temperature = 57.4713, Current Cost = 22, Best Cost = 8
# Iteration 75: Temperature = 57.1429, Current Cost = 22, Best Cost = 8
# Iteration 76: Temperature = 56.8182, Current Cost = 22, Best Cost = 8
# Iteration 77: Temperature = 56.4972, Current Cost = 26, Best Cost = 8
# Iteration 78: Temperature = 56.1798, Current Cost = 26, Best Cost = 8
# Iteration 79: Temperature = 55.8659, Current Cost = 26, Best Cost = 8
# Iteration 80: Temperature = 55.5556, Current Cost = 22, Best Cost = 8
# Iteration 81: Temperature = 55.2486, Current Cost = 22, Best Cost = 8
# Iteration 82: Temperature = 54.9451, Current Cost = 22, Best Cost = 8
# Iteration 83: Temperature = 54.6448, Current Cost = 26, Best Cost = 8
# Iteration 84: Temperature = 54.3478, Current Cost = 22, Best Cost = 8
# Iteration 85: Temperature = 54.0541, Current Cost = 26, Best Cost = 8
# Iteration 86: Temperature = 53.7634, Current Cost = 26, Best Cost = 8
# Iteration 87: Temperature = 53.4759, Current Cost = 26, Best Cost = 8
# Iteration 88: Temperature = 53.1915, Current Cost = 24, Best Cost = 8
# Iteration 89: Temperature = 52.9101, Current Cost = 24, Best Cost = 8
# Iteration 90: Temperature = 52.6316, Current Cost = 28, Best Cost = 8
# Iteration 91: Temperature = 52.3560, Current Cost = 30, Best Cost = 8
# Iteration 92: Temperature = 52.0833, Current Cost = 28, Best Cost = 8
# Iteration 93: Temperature = 51.8135, Current Cost = 24, Best Cost = 8
# Iteration 94: Temperature = 51.5464, Current Cost = 24, Best Cost = 8
# Iteration 95: Temperature = 51.2821, Current Cost = 24, Best Cost = 8
# Iteration 96: Temperature = 51.0204, Current Cost = 26, Best Cost = 8
# Iteration 97: Temperature = 50.7614, Current Cost = 26, Best Cost = 8
# Iteration 98: Temperature = 50.5051, Current Cost = 24, Best Cost = 8
# Iteration 99: Temperature = 50.2513, Current Cost = 24, Best Cost = 8
# Iteration 100: Temperature = 50.0000, Current Cost = 24, Best Cost = 8
# Iteration 101: Temperature = 49.7512, Current Cost = 28, Best Cost = 8
# Iteration 102: Temperature = 49.5050, Current Cost = 30, Best Cost = 8
# Iteration 103: Temperature = 49.2611, Current Cost = 28, Best Cost = 8
# Iteration 104: Temperature = 49.0196, Current Cost = 28, Best Cost = 8
# Iteration 105: Temperature = 48.7805, Current Cost = 30, Best Cost = 8
# Iteration 106: Temperature = 48.5437, Current Cost = 31, Best Cost = 8
# Iteration 107: Temperature = 48.3092, Current Cost = 30, Best Cost = 8
# Iteration 108: Temperature = 48.0769, Current Cost = 31, Best Cost = 8
# Iteration 109: Temperature = 47.8469, Current Cost = 32, Best Cost = 8
# Iteration 110: Temperature = 47.6190, Current Cost = 35, Best Cost = 8
# Iteration 111: Temperature = 47.3934, Current Cost = 32, Best Cost = 8
# Iteration 112: Temperature = 47.1698, Current Cost = 28, Best Cost = 8
# Iteration 113: Temperature = 46.9484, Current Cost = 28, Best Cost = 8
# Iteration 114: Temperature = 46.7290, Current Cost = 28, Best Cost = 8
# Iteration 115: Temperature = 46.5116, Current Cost = 28, Best Cost = 8
# Iteration 116: Temperature = 46.2963, Current Cost = 24, Best Cost = 8
# Iteration 117: Temperature = 46.0829, Current Cost = 28, Best Cost = 8
# Iteration 118: Temperature = 45.8716, Current Cost = 27, Best Cost = 8
# Iteration 119: Temperature = 45.6621, Current Cost = 28, Best Cost = 8
# Iteration 120: Temperature = 45.4545, Current Cost = 29, Best Cost = 8
# Iteration 121: Temperature = 45.2489, Current Cost = 28, Best Cost = 8
# Iteration 122: Temperature = 45.0450, Current Cost = 29, Best Cost = 8
# Iteration 123: Temperature = 44.8430, Current Cost = 28, Best Cost = 8
# Iteration 124: Temperature = 44.6429, Current Cost = 29, Best Cost = 8
# Iteration 125: Temperature = 44.4444, Current Cost = 28, Best Cost = 8
# Iteration 126: Temperature = 44.2478, Current Cost = 27, Best Cost = 8
# Iteration 127: Temperature = 44.0529, Current Cost = 26, Best Cost = 8
# Iteration 128: Temperature = 43.8596, Current Cost = 27, Best Cost = 8
# Iteration 129: Temperature = 43.6681, Current Cost = 28, Best Cost = 8
# Iteration 130: Temperature = 43.4783, Current Cost = 24, Best Cost = 8
# Iteration 131: Temperature = 43.2900, Current Cost = 28, Best Cost = 8
# Iteration 132: Temperature = 43.1034, Current Cost = 27, Best Cost = 8
# Iteration 133: Temperature = 42.9185, Current Cost = 26, Best Cost = 8
# Iteration 134: Temperature = 42.7350, Current Cost = 28, Best Cost = 8
# Iteration 135: Temperature = 42.5532, Current Cost = 28, Best Cost = 8
# Iteration 136: Temperature = 42.3729, Current Cost = 24, Best Cost = 8
# Iteration 137: Temperature = 42.1941, Current Cost = 24, Best Cost = 8
# Iteration 138: Temperature = 42.0168, Current Cost = 20, Best Cost = 8
# Iteration 139: Temperature = 41.8410, Current Cost = 20, Best Cost = 8
# Iteration 140: Temperature = 41.6667, Current Cost = 16, Best Cost = 8
# Iteration 141: Temperature = 41.4938, Current Cost = 16, Best Cost = 8
# Iteration 142: Temperature = 41.3223, Current Cost = 20, Best Cost = 8
# Iteration 143: Temperature = 41.1523, Current Cost = 20, Best Cost = 8
# Iteration 144: Temperature = 40.9836, Current Cost = 19, Best Cost = 8
# Iteration 145: Temperature = 40.8163, Current Cost = 22, Best Cost = 8
# Iteration 146: Temperature = 40.6504, Current Cost = 23, Best Cost = 8
# Iteration 147: Temperature = 40.4858, Current Cost = 26, Best Cost = 8
# Iteration 148: Temperature = 40.3226, Current Cost = 23, Best Cost = 8
# Iteration 149: Temperature = 40.1606, Current Cost = 20, Best Cost = 8
# Iteration 150: Temperature = 40.0000, Current Cost = 20, Best Cost = 8
# Iteration 151: Temperature = 39.8406, Current Cost = 20, Best Cost = 8
# Iteration 152: Temperature = 39.6825, Current Cost = 20, Best Cost = 8
# Iteration 153: Temperature = 39.5257, Current Cost = 20, Best Cost = 8
# Iteration 154: Temperature = 39.3701, Current Cost = 20, Best Cost = 8
# Iteration 155: Temperature = 39.2157, Current Cost = 20, Best Cost = 8
# Iteration 156: Temperature = 39.0625, Current Cost = 20, Best Cost = 8
# Iteration 157: Temperature = 38.9105, Current Cost = 20, Best Cost = 8
# Iteration 158: Temperature = 38.7597, Current Cost = 20, Best Cost = 8
# Iteration 159: Temperature = 38.6100, Current Cost = 16, Best Cost = 8
# Iteration 160: Temperature = 38.4615, Current Cost = 16, Best Cost = 8
# Iteration 161: Temperature = 38.3142, Current Cost = 16, Best Cost = 8
# Iteration 162: Temperature = 38.1679, Current Cost = 16, Best Cost = 8
# Iteration 163: Temperature = 38.0228, Current Cost = 16, Best Cost = 8
# Iteration 164: Temperature = 37.8788, Current Cost = 18, Best Cost = 8
# Iteration 165: Temperature = 37.7358, Current Cost = 22, Best Cost = 8
# Iteration 166: Temperature = 37.5940, Current Cost = 26, Best Cost = 8
# Iteration 167: Temperature = 37.4532, Current Cost = 22, Best Cost = 8
# Iteration 168: Temperature = 37.3134, Current Cost = 22, Best Cost = 8
# Iteration 169: Temperature = 37.1747, Current Cost = 20, Best Cost = 8
# Iteration 170: Temperature = 37.0370, Current Cost = 20, Best Cost = 8
# Iteration 171: Temperature = 36.9004, Current Cost = 16, Best Cost = 8
# Iteration 172: Temperature = 36.7647, Current Cost = 16, Best Cost = 8
# Iteration 173: Temperature = 36.6300, Current Cost = 16, Best Cost = 8
# Iteration 174: Temperature = 36.4964, Current Cost = 12, Best Cost = 8
# Iteration 175: Temperature = 36.3636, Current Cost = 12, Best Cost = 8
# Iteration 176: Temperature = 36.2319, Current Cost = 12, Best Cost = 8
# Iteration 177: Temperature = 36.1011, Current Cost = 10, Best Cost = 8
# Iteration 178: Temperature = 35.9712, Current Cost = 10, Best Cost = 8
# Iteration 179: Temperature = 35.8423, Current Cost = 10, Best Cost = 8
# Iteration 180: Temperature = 35.7143, Current Cost = 10, Best Cost = 8
# Iteration 181: Temperature = 35.5872, Current Cost = 10, Best Cost = 8
# Iteration 182: Temperature = 35.4610, Current Cost = 10, Best Cost = 8
# Iteration 183: Temperature = 35.3357, Current Cost = 10, Best Cost = 8
# Iteration 184: Temperature = 35.2113, Current Cost = 10, Best Cost = 8
# Iteration 185: Temperature = 35.0877, Current Cost = 12, Best Cost = 8
# Iteration 186: Temperature = 34.9650, Current Cost = 12, Best Cost = 8
# Iteration 187: Temperature = 34.8432, Current Cost = 13, Best Cost = 8
# Iteration 188: Temperature = 34.7222, Current Cost = 16, Best Cost = 8
# Iteration 189: Temperature = 34.6021, Current Cost = 17, Best Cost = 8
# Iteration 190: Temperature = 34.4828, Current Cost = 18, Best Cost = 8
# Iteration 191: Temperature = 34.3643, Current Cost = 21, Best Cost = 8
# Iteration 192: Temperature = 34.2466, Current Cost = 18, Best Cost = 8
# Iteration 193: Temperature = 34.1297, Current Cost = 17, Best Cost = 8
# Iteration 194: Temperature = 34.0136, Current Cost = 16, Best Cost = 8
# Iteration 195: Temperature = 33.8983, Current Cost = 15, Best Cost = 8
# Iteration 196: Temperature = 33.7838, Current Cost = 16, Best Cost = 8
# Iteration 197: Temperature = 33.6700, Current Cost = 17, Best Cost = 8
# Iteration 198: Temperature = 33.5570, Current Cost = 16, Best Cost = 8
# Iteration 199: Temperature = 33.4448, Current Cost = 15, Best Cost = 8
# Iteration 200: Temperature = 33.3333, Current Cost = 18, Best Cost = 8
# Iteration 201: Temperature = 33.2226, Current Cost = 15, Best Cost = 8
# Iteration 202: Temperature = 33.1126, Current Cost = 16, Best Cost = 8
# Iteration 203: Temperature = 33.0033, Current Cost = 13, Best Cost = 8
# Iteration 204: Temperature = 32.8947, Current Cost = 12, Best Cost = 8
# Iteration 205: Temperature = 32.7869, Current Cost = 11, Best Cost = 8
# Iteration 206: Temperature = 32.6797, Current Cost = 12, Best Cost = 8
# Iteration 207: Temperature = 32.5733, Current Cost = 12, Best Cost = 8
# Iteration 208: Temperature = 32.4675, Current Cost = 12, Best Cost = 8
# Iteration 209: Temperature = 32.3625, Current Cost = 11, Best Cost = 8
# Iteration 210: Temperature = 32.2581, Current Cost = 14, Best Cost = 8
# Iteration 211: Temperature = 32.1543, Current Cost = 13, Best Cost = 8
# Iteration 212: Temperature = 32.0513, Current Cost = 12, Best Cost = 8
# Iteration 213: Temperature = 31.9489, Current Cost = 13, Best Cost = 8
# Iteration 214: Temperature = 31.8471, Current Cost = 14, Best Cost = 8
# Iteration 215: Temperature = 31.7460, Current Cost = 15, Best Cost = 8
# Iteration 216: Temperature = 31.6456, Current Cost = 18, Best Cost = 8
# Iteration 217: Temperature = 31.5457, Current Cost = 19, Best Cost = 8
# Iteration 218: Temperature = 31.4465, Current Cost = 20, Best Cost = 8
# Iteration 219: Temperature = 31.3480, Current Cost = 16, Best Cost = 8
# Iteration 220: Temperature = 31.2500, Current Cost = 18, Best Cost = 8
# Iteration 221: Temperature = 31.1526, Current Cost = 18, Best Cost = 8
# Iteration 222: Temperature = 31.0559, Current Cost = 18, Best Cost = 8
# Iteration 223: Temperature = 30.9598, Current Cost = 16, Best Cost = 8
# Iteration 224: Temperature = 30.8642, Current Cost = 18, Best Cost = 8
# Iteration 225: Temperature = 30.7692, Current Cost = 18, Best Cost = 8
# Iteration 226: Temperature = 30.6748, Current Cost = 22, Best Cost = 8
# Iteration 227: Temperature = 30.5810, Current Cost = 22, Best Cost = 8
# Iteration 228: Temperature = 30.4878, Current Cost = 24, Best Cost = 8
# Iteration 229: Temperature = 30.3951, Current Cost = 24, Best Cost = 8
# Iteration 230: Temperature = 30.3030, Current Cost = 22, Best Cost = 8
# Iteration 231: Temperature = 30.2115, Current Cost = 20, Best Cost = 8
# Iteration 232: Temperature = 30.1205, Current Cost = 18, Best Cost = 8
# Iteration 233: Temperature = 30.0300, Current Cost = 20, Best Cost = 8
# Iteration 234: Temperature = 29.9401, Current Cost = 18, Best Cost = 8
# Iteration 235: Temperature = 29.8507, Current Cost = 20, Best Cost = 8
# Iteration 236: Temperature = 29.7619, Current Cost = 21, Best Cost = 8
# Iteration 237: Temperature = 29.6736, Current Cost = 22, Best Cost = 8
# Iteration 238: Temperature = 29.5858, Current Cost = 19, Best Cost = 8
# Iteration 239: Temperature = 29.4985, Current Cost = 20, Best Cost = 8
# Iteration 240: Temperature = 29.4118, Current Cost = 17, Best Cost = 8
# Iteration 241: Temperature = 29.3255, Current Cost = 14, Best Cost = 8
# Iteration 242: Temperature = 29.2398, Current Cost = 14, Best Cost = 8
# Iteration 243: Temperature = 29.1545, Current Cost = 14, Best Cost = 8
# Iteration 244: Temperature = 29.0698, Current Cost = 18, Best Cost = 8
# Iteration 245: Temperature = 28.9855, Current Cost = 22, Best Cost = 8
# Iteration 246: Temperature = 28.9017, Current Cost = 22, Best Cost = 8
# Iteration 247: Temperature = 28.8184, Current Cost = 26, Best Cost = 8
# Iteration 248: Temperature = 28.7356, Current Cost = 22, Best Cost = 8
# Iteration 249: Temperature = 28.6533, Current Cost = 22, Best Cost = 8
# Iteration 250: Temperature = 28.5714, Current Cost = 18, Best Cost = 8
# Iteration 251: Temperature = 28.4900, Current Cost = 22, Best Cost = 8
# Iteration 252: Temperature = 28.4091, Current Cost = 22, Best Cost = 8
# Iteration 253: Temperature = 28.3286, Current Cost = 22, Best Cost = 8
# Iteration 254: Temperature = 28.2486, Current Cost = 18, Best Cost = 8
# Iteration 255: Temperature = 28.1690, Current Cost = 22, Best Cost = 8
# Iteration 256: Temperature = 28.0899, Current Cost = 22, Best Cost = 8
# Iteration 257: Temperature = 28.0112, Current Cost = 22, Best Cost = 8
# Iteration 258: Temperature = 27.9330, Current Cost = 22, Best Cost = 8
# Iteration 259: Temperature = 27.8552, Current Cost = 22, Best Cost = 8
# Iteration 260: Temperature = 27.7778, Current Cost = 22, Best Cost = 8
# Iteration 261: Temperature = 27.7008, Current Cost = 26, Best Cost = 8
# Iteration 262: Temperature = 27.6243, Current Cost = 22, Best Cost = 8
# Iteration 263: Temperature = 27.5482, Current Cost = 26, Best Cost = 8
# Iteration 264: Temperature = 27.4725, Current Cost = 26, Best Cost = 8
# Iteration 265: Temperature = 27.3973, Current Cost = 22, Best Cost = 8
# Iteration 266: Temperature = 27.3224, Current Cost = 26, Best Cost = 8
# Iteration 267: Temperature = 27.2480, Current Cost = 26, Best Cost = 8
# Iteration 268: Temperature = 27.1739, Current Cost = 26, Best Cost = 8
# Iteration 269: Temperature = 27.1003, Current Cost = 26, Best Cost = 8
# Iteration 270: Temperature = 27.0270, Current Cost = 26, Best Cost = 8
# Iteration 271: Temperature = 26.9542, Current Cost = 26, Best Cost = 8
# Iteration 272: Temperature = 26.8817, Current Cost = 26, Best Cost = 8
# Iteration 273: Temperature = 26.8097, Current Cost = 26, Best Cost = 8
# Iteration 274: Temperature = 26.7380, Current Cost = 26, Best Cost = 8
# Iteration 275: Temperature = 26.6667, Current Cost = 26, Best Cost = 8
# Iteration 276: Temperature = 26.5957, Current Cost = 22, Best Cost = 8
# Iteration 277: Temperature = 26.5252, Current Cost = 18, Best Cost = 8
# Iteration 278: Temperature = 26.4550, Current Cost = 18, Best Cost = 8
# Iteration 279: Temperature = 26.3852, Current Cost = 14, Best Cost = 8
# Iteration 280: Temperature = 26.3158, Current Cost = 14, Best Cost = 8
# Iteration 281: Temperature = 26.2467, Current Cost = 14, Best Cost = 8
# Iteration 282: Temperature = 26.1780, Current Cost = 14, Best Cost = 8
# Iteration 283: Temperature = 26.1097, Current Cost = 12, Best Cost = 8
# Iteration 284: Temperature = 26.0417, Current Cost = 12, Best Cost = 8
# Iteration 285: Temperature = 25.9740, Current Cost = 12, Best Cost = 8
# Iteration 286: Temperature = 25.9067, Current Cost = 12, Best Cost = 8
# Iteration 287: Temperature = 25.8398, Current Cost = 12, Best Cost = 8
# Iteration 288: Temperature = 25.7732, Current Cost = 10, Best Cost = 8
# Iteration 289: Temperature = 25.7069, Current Cost = 10, Best Cost = 8
# Iteration 290: Temperature = 25.6410, Current Cost = 10, Best Cost = 8
# Iteration 291: Temperature = 25.5754, Current Cost = 10, Best Cost = 8
# Iteration 292: Temperature = 25.5102, Current Cost = 10, Best Cost = 8
# Iteration 293: Temperature = 25.4453, Current Cost = 10, Best Cost = 8
# Iteration 294: Temperature = 25.3807, Current Cost = 10, Best Cost = 8
# Iteration 295: Temperature = 25.3165, Current Cost = 10, Best Cost = 8
# Iteration 296: Temperature = 25.2525, Current Cost = 10, Best Cost = 8
# Iteration 297: Temperature = 25.1889, Current Cost = 10, Best Cost = 8
# Iteration 298: Temperature = 25.1256, Current Cost = 10, Best Cost = 8
# Iteration 299: Temperature = 25.0627, Current Cost = 10, Best Cost = 8
# Iteration 300: Temperature = 25.0000, Current Cost = 12, Best Cost = 8
# Iteration 301: Temperature = 24.9377, Current Cost = 16, Best Cost = 8
# Iteration 302: Temperature = 24.8756, Current Cost = 20, Best Cost = 8
# Iteration 303: Temperature = 24.8139, Current Cost = 20, Best Cost = 8
# Iteration 304: Temperature = 24.7525, Current Cost = 20, Best Cost = 8
# Iteration 305: Temperature = 24.6914, Current Cost = 20, Best Cost = 8
# Iteration 306: Temperature = 24.6305, Current Cost = 20, Best Cost = 8
# Iteration 307: Temperature = 24.5700, Current Cost = 20, Best Cost = 8
# Iteration 308: Temperature = 24.5098, Current Cost = 20, Best Cost = 8
# Iteration 309: Temperature = 24.4499, Current Cost = 20, Best Cost = 8
# Iteration 310: Temperature = 24.3902, Current Cost = 24, Best Cost = 8
# Iteration 311: Temperature = 24.3309, Current Cost = 24, Best Cost = 8
# Iteration 312: Temperature = 24.2718, Current Cost = 24, Best Cost = 8
# Iteration 313: Temperature = 24.2131, Current Cost = 24, Best Cost = 8
# Iteration 314: Temperature = 24.1546, Current Cost = 24, Best Cost = 8
# Iteration 315: Temperature = 24.0964, Current Cost = 24, Best Cost = 8
# Iteration 316: Temperature = 24.0385, Current Cost = 24, Best Cost = 8
# Iteration 317: Temperature = 23.9808, Current Cost = 24, Best Cost = 8
# Iteration 318: Temperature = 23.9234, Current Cost = 24, Best Cost = 8
# Iteration 319: Temperature = 23.8663, Current Cost = 20, Best Cost = 8
# Iteration 320: Temperature = 23.8095, Current Cost = 20, Best Cost = 8
# Iteration 321: Temperature = 23.7530, Current Cost = 20, Best Cost = 8
# Iteration 322: Temperature = 23.6967, Current Cost = 20, Best Cost = 8
# Iteration 323: Temperature = 23.6407, Current Cost = 20, Best Cost = 8
# Iteration 324: Temperature = 23.5849, Current Cost = 20, Best Cost = 8
# Iteration 325: Temperature = 23.5294, Current Cost = 20, Best Cost = 8
# Iteration 326: Temperature = 23.4742, Current Cost = 24, Best Cost = 8
# Iteration 327: Temperature = 23.4192, Current Cost = 24, Best Cost = 8
# Iteration 328: Temperature = 23.3645, Current Cost = 24, Best Cost = 8
# Iteration 329: Temperature = 23.3100, Current Cost = 24, Best Cost = 8
# Iteration 330: Temperature = 23.2558, Current Cost = 20, Best Cost = 8
# Iteration 331: Temperature = 23.2019, Current Cost = 20, Best Cost = 8
# Iteration 332: Temperature = 23.1481, Current Cost = 16, Best Cost = 8
# Iteration 333: Temperature = 23.0947, Current Cost = 16, Best Cost = 8
# Iteration 334: Temperature = 23.0415, Current Cost = 20, Best Cost = 8
# Iteration 335: Temperature = 22.9885, Current Cost = 20, Best Cost = 8
# Iteration 336: Temperature = 22.9358, Current Cost = 20, Best Cost = 8
# Iteration 337: Temperature = 22.8833, Current Cost = 16, Best Cost = 8
# Iteration 338: Temperature = 22.8311, Current Cost = 18, Best Cost = 8
# Iteration 339: Temperature = 22.7790, Current Cost = 22, Best Cost = 8
# Iteration 340: Temperature = 22.7273, Current Cost = 22, Best Cost = 8
# Iteration 341: Temperature = 22.6757, Current Cost = 22, Best Cost = 8
# Iteration 342: Temperature = 22.6244, Current Cost = 22, Best Cost = 8
# Iteration 343: Temperature = 22.5734, Current Cost = 20, Best Cost = 8
# Iteration 344: Temperature = 22.5225, Current Cost = 16, Best Cost = 8
# Iteration 345: Temperature = 22.4719, Current Cost = 16, Best Cost = 8
# Iteration 346: Temperature = 22.4215, Current Cost = 12, Best Cost = 8
# Iteration 347: Temperature = 22.3714, Current Cost = 12, Best Cost = 8
# Iteration 348: Temperature = 22.3214, Current Cost = 12, Best Cost = 8
# Iteration 349: Temperature = 22.2717, Current Cost = 12, Best Cost = 8
# Iteration 350: Temperature = 22.2222, Current Cost = 12, Best Cost = 8
# Iteration 351: Temperature = 22.1729, Current Cost = 12, Best Cost = 8
# Iteration 352: Temperature = 22.1239, Current Cost = 12, Best Cost = 8
# Iteration 353: Temperature = 22.0751, Current Cost = 12, Best Cost = 8
# Iteration 354: Temperature = 22.0264, Current Cost = 12, Best Cost = 8
# Iteration 355: Temperature = 21.9780, Current Cost = 12, Best Cost = 8
# Iteration 356: Temperature = 21.9298, Current Cost = 12, Best Cost = 8
# Iteration 357: Temperature = 21.8818, Current Cost = 16, Best Cost = 8
# Iteration 358: Temperature = 21.8341, Current Cost = 16, Best Cost = 8
# Iteration 359: Temperature = 21.7865, Current Cost = 16, Best Cost = 8
# Iteration 360: Temperature = 21.7391, Current Cost = 12, Best Cost = 8
# Iteration 361: Temperature = 21.6920, Current Cost = 12, Best Cost = 8
# Iteration 362: Temperature = 21.6450, Current Cost = 12, Best Cost = 8
# Iteration 363: Temperature = 21.5983, Current Cost = 12, Best Cost = 8
# Iteration 364: Temperature = 21.5517, Current Cost = 12, Best Cost = 8
# Iteration 365: Temperature = 21.5054, Current Cost = 12, Best Cost = 8
# Iteration 366: Temperature = 21.4592, Current Cost = 12, Best Cost = 8
# Iteration 367: Temperature = 21.4133, Current Cost = 10, Best Cost = 8
# Iteration 368: Temperature = 21.3675, Current Cost = 10, Best Cost = 8
# Iteration 369: Temperature = 21.3220, Current Cost = 10, Best Cost = 8
# Iteration 370: Temperature = 21.2766, Current Cost = 12, Best Cost = 8
# Iteration 371: Temperature = 21.2314, Current Cost = 12, Best Cost = 8
# Iteration 372: Temperature = 21.1864, Current Cost = 12, Best Cost = 8
# Iteration 373: Temperature = 21.1416, Current Cost = 12, Best Cost = 8
# Iteration 374: Temperature = 21.0970, Current Cost = 10, Best Cost = 8
# Iteration 375: Temperature = 21.0526, Current Cost = 10, Best Cost = 8
# Iteration 376: Temperature = 21.0084, Current Cost = 10, Best Cost = 8
# Iteration 377: Temperature = 20.9644, Current Cost = 10, Best Cost = 8
# Iteration 378: Temperature = 20.9205, Current Cost = 10, Best Cost = 8
# Iteration 379: Temperature = 20.8768, Current Cost = 10, Best Cost = 8
# Iteration 380: Temperature = 20.8333, Current Cost = 10, Best Cost = 8
# Iteration 381: Temperature = 20.7900, Current Cost = 10, Best Cost = 8
# Iteration 382: Temperature = 20.7469, Current Cost = 10, Best Cost = 8
# Iteration 383: Temperature = 20.7039, Current Cost = 10, Best Cost = 8
# Iteration 384: Temperature = 20.6612, Current Cost = 10, Best Cost = 8
# Iteration 385: Temperature = 20.6186, Current Cost = 10, Best Cost = 8
# Iteration 386: Temperature = 20.5761, Current Cost = 10, Best Cost = 8
# Iteration 387: Temperature = 20.5339, Current Cost = 10, Best Cost = 8
# Iteration 388: Temperature = 20.4918, Current Cost = 10, Best Cost = 8
# Iteration 389: Temperature = 20.4499, Current Cost = 10, Best Cost = 8
# Iteration 390: Temperature = 20.4082, Current Cost = 10, Best Cost = 8
# Iteration 391: Temperature = 20.3666, Current Cost = 10, Best Cost = 8
# Iteration 392: Temperature = 20.3252, Current Cost = 10, Best Cost = 8
# Iteration 393: Temperature = 20.2840, Current Cost = 10, Best Cost = 8
# Iteration 394: Temperature = 20.2429, Current Cost = 10, Best Cost = 8
# Iteration 395: Temperature = 20.2020, Current Cost = 10, Best Cost = 8
# Iteration 396: Temperature = 20.1613, Current Cost = 10, Best Cost = 8
# Iteration 397: Temperature = 20.1207, Current Cost = 10, Best Cost = 8
# Iteration 398: Temperature = 20.0803, Current Cost = 10, Best Cost = 8
# Iteration 399: Temperature = 20.0401, Current Cost = 10, Best Cost = 8
# Iteration 400: Temperature = 20.0000, Current Cost = 10, Best Cost = 8
# Iteration 401: Temperature = 19.9601, Current Cost = 10, Best Cost = 8
# Iteration 402: Temperature = 19.9203, Current Cost = 10, Best Cost = 8
# Iteration 403: Temperature = 19.8807, Current Cost = 12, Best Cost = 8
# Iteration 404: Temperature = 19.8413, Current Cost = 12, Best Cost = 8
# Iteration 405: Temperature = 19.8020, Current Cost = 14, Best Cost = 8
# Iteration 406: Temperature = 19.7628, Current Cost = 14, Best Cost = 8
# Iteration 407: Temperature = 19.7239, Current Cost = 14, Best Cost = 8
# Iteration 408: Temperature = 19.6850, Current Cost = 14, Best Cost = 8
# Iteration 409: Temperature = 19.6464, Current Cost = 14, Best Cost = 8
# Iteration 410: Temperature = 19.6078, Current Cost = 14, Best Cost = 8
# Iteration 411: Temperature = 19.5695, Current Cost = 12, Best Cost = 8
# Iteration 412: Temperature = 19.5312, Current Cost = 12, Best Cost = 8
# Iteration 413: Temperature = 19.4932, Current Cost = 12, Best Cost = 8
# Iteration 414: Temperature = 19.4553, Current Cost = 10, Best Cost = 8
# Iteration 415: Temperature = 19.4175, Current Cost = 10, Best Cost = 8
# Iteration 416: Temperature = 19.3798, Current Cost = 10, Best Cost = 8
# Iteration 417: Temperature = 19.3424, Current Cost = 10, Best Cost = 8
# Iteration 418: Temperature = 19.3050, Current Cost = 10, Best Cost = 8
# Iteration 419: Temperature = 19.2678, Current Cost = 12, Best Cost = 8
# Iteration 420: Temperature = 19.2308, Current Cost = 12, Best Cost = 8
# Iteration 421: Temperature = 19.1939, Current Cost = 10, Best Cost = 8
# Iteration 422: Temperature = 19.1571, Current Cost = 10, Best Cost = 8
# Iteration 423: Temperature = 19.1205, Current Cost = 10, Best Cost = 8
# Iteration 424: Temperature = 19.0840, Current Cost = 10, Best Cost = 8
# Iteration 425: Temperature = 19.0476, Current Cost = 10, Best Cost = 8
# Iteration 426: Temperature = 19.0114, Current Cost = 10, Best Cost = 8
# Iteration 427: Temperature = 18.9753, Current Cost = 12, Best Cost = 8
# Iteration 428: Temperature = 18.9394, Current Cost = 12, Best Cost = 8
# Iteration 429: Temperature = 18.9036, Current Cost = 16, Best Cost = 8
# Iteration 430: Temperature = 18.8679, Current Cost = 16, Best Cost = 8
# Iteration 431: Temperature = 18.8324, Current Cost = 16, Best Cost = 8
# Iteration 432: Temperature = 18.7970, Current Cost = 20, Best Cost = 8
# Iteration 433: Temperature = 18.7617, Current Cost = 20, Best Cost = 8
# Iteration 434: Temperature = 18.7266, Current Cost = 20, Best Cost = 8
# Iteration 435: Temperature = 18.6916, Current Cost = 20, Best Cost = 8
# Iteration 436: Temperature = 18.6567, Current Cost = 16, Best Cost = 8
# Iteration 437: Temperature = 18.6220, Current Cost = 16, Best Cost = 8
# Iteration 438: Temperature = 18.5874, Current Cost = 18, Best Cost = 8
# Iteration 439: Temperature = 18.5529, Current Cost = 16, Best Cost = 8
# Iteration 440: Temperature = 18.5185, Current Cost = 16, Best Cost = 8
# Iteration 441: Temperature = 18.4843, Current Cost = 16, Best Cost = 8
# Iteration 442: Temperature = 18.4502, Current Cost = 16, Best Cost = 8
# Iteration 443: Temperature = 18.4162, Current Cost = 16, Best Cost = 8
# Iteration 444: Temperature = 18.3824, Current Cost = 20, Best Cost = 8
# Iteration 445: Temperature = 18.3486, Current Cost = 20, Best Cost = 8
# Iteration 446: Temperature = 18.3150, Current Cost = 20, Best Cost = 8
# Iteration 447: Temperature = 18.2815, Current Cost = 20, Best Cost = 8
# Iteration 448: Temperature = 18.2482, Current Cost = 20, Best Cost = 8
# Iteration 449: Temperature = 18.2149, Current Cost = 16, Best Cost = 8
# Iteration 450: Temperature = 18.1818, Current Cost = 16, Best Cost = 8
# Iteration 451: Temperature = 18.1488, Current Cost = 16, Best Cost = 8
# Iteration 452: Temperature = 18.1159, Current Cost = 18, Best Cost = 8
# Iteration 453: Temperature = 18.0832, Current Cost = 18, Best Cost = 8
# Iteration 454: Temperature = 18.0505, Current Cost = 22, Best Cost = 8
# Iteration 455: Temperature = 18.0180, Current Cost = 22, Best Cost = 8
# Iteration 456: Temperature = 17.9856, Current Cost = 26, Best Cost = 8
# Iteration 457: Temperature = 17.9533, Current Cost = 26, Best Cost = 8
# Iteration 458: Temperature = 17.9211, Current Cost = 26, Best Cost = 8
# Iteration 459: Temperature = 17.8891, Current Cost = 26, Best Cost = 8
# Iteration 460: Temperature = 17.8571, Current Cost = 30, Best Cost = 8
# Iteration 461: Temperature = 17.8253, Current Cost = 26, Best Cost = 8
# Iteration 462: Temperature = 17.7936, Current Cost = 30, Best Cost = 8
# Iteration 463: Temperature = 17.7620, Current Cost = 34, Best Cost = 8
# Iteration 464: Temperature = 17.7305, Current Cost = 34, Best Cost = 8
# Iteration 465: Temperature = 17.6991, Current Cost = 30, Best Cost = 8
# Iteration 466: Temperature = 17.6678, Current Cost = 30, Best Cost = 8
# Iteration 467: Temperature = 17.6367, Current Cost = 30, Best Cost = 8
# Iteration 468: Temperature = 17.6056, Current Cost = 26, Best Cost = 8
# Iteration 469: Temperature = 17.5747, Current Cost = 26, Best Cost = 8
# Iteration 470: Temperature = 17.5439, Current Cost = 26, Best Cost = 8
# Iteration 471: Temperature = 17.5131, Current Cost = 22, Best Cost = 8
# Iteration 472: Temperature = 17.4825, Current Cost = 22, Best Cost = 8
# Iteration 473: Temperature = 17.4520, Current Cost = 22, Best Cost = 8
# Iteration 474: Temperature = 17.4216, Current Cost = 22, Best Cost = 8
# Iteration 475: Temperature = 17.3913, Current Cost = 22, Best Cost = 8
# Iteration 476: Temperature = 17.3611, Current Cost = 26, Best Cost = 8
# Iteration 477: Temperature = 17.3310, Current Cost = 30, Best Cost = 8
# Iteration 478: Temperature = 17.3010, Current Cost = 30, Best Cost = 8
# Iteration 479: Temperature = 17.2712, Current Cost = 30, Best Cost = 8
# Iteration 480: Temperature = 17.2414, Current Cost = 30, Best Cost = 8
# Iteration 481: Temperature = 17.2117, Current Cost = 34, Best Cost = 8
# Iteration 482: Temperature = 17.1821, Current Cost = 30, Best Cost = 8
# Iteration 483: Temperature = 17.1527, Current Cost = 26, Best Cost = 8
# Iteration 484: Temperature = 17.1233, Current Cost = 26, Best Cost = 8
# Iteration 485: Temperature = 17.0940, Current Cost = 26, Best Cost = 8
# Iteration 486: Temperature = 17.0648, Current Cost = 30, Best Cost = 8
# Iteration 487: Temperature = 17.0358, Current Cost = 34, Best Cost = 8
# Iteration 488: Temperature = 17.0068, Current Cost = 34, Best Cost = 8
# Iteration 489: Temperature = 16.9779, Current Cost = 34, Best Cost = 8
# Iteration 490: Temperature = 16.9492, Current Cost = 38, Best Cost = 8
# Iteration 491: Temperature = 16.9205, Current Cost = 38, Best Cost = 8
# Iteration 492: Temperature = 16.8919, Current Cost = 38, Best Cost = 8
# Iteration 493: Temperature = 16.8634, Current Cost = 42, Best Cost = 8
# Iteration 494: Temperature = 16.8350, Current Cost = 46, Best Cost = 8
# Iteration 495: Temperature = 16.8067, Current Cost = 46, Best Cost = 8
# Iteration 496: Temperature = 16.7785, Current Cost = 46, Best Cost = 8
# Iteration 497: Temperature = 16.7504, Current Cost = 46, Best Cost = 8
# Iteration 498: Temperature = 16.7224, Current Cost = 46, Best Cost = 8
# Iteration 499: Temperature = 16.6945, Current Cost = 42, Best Cost = 8
# Iteration 500: Temperature = 16.6667, Current Cost = 42, Best Cost = 8
# Iteration 501: Temperature = 16.6389, Current Cost = 38, Best Cost = 8
# Iteration 502: Temperature = 16.6113, Current Cost = 42, Best Cost = 8
# Iteration 503: Temperature = 16.5837, Current Cost = 38, Best Cost = 8
# Iteration 504: Temperature = 16.5563, Current Cost = 38, Best Cost = 8
# Iteration 505: Temperature = 16.5289, Current Cost = 34, Best Cost = 8
# Iteration 506: Temperature = 16.5017, Current Cost = 34, Best Cost = 8
# Iteration 507: Temperature = 16.4745, Current Cost = 30, Best Cost = 8
# Iteration 508: Temperature = 16.4474, Current Cost = 30, Best Cost = 8
# Iteration 509: Temperature = 16.4204, Current Cost = 30, Best Cost = 8
# Iteration 510: Temperature = 16.3934, Current Cost = 26, Best Cost = 8
# Iteration 511: Temperature = 16.3666, Current Cost = 26, Best Cost = 8
# Iteration 512: Temperature = 16.3399, Current Cost = 30, Best Cost = 8
# Iteration 513: Temperature = 16.3132, Current Cost = 30, Best Cost = 8
# Iteration 514: Temperature = 16.2866, Current Cost = 30, Best Cost = 8
# Iteration 515: Temperature = 16.2602, Current Cost = 26, Best Cost = 8
# Iteration 516: Temperature = 16.2338, Current Cost = 26, Best Cost = 8
# Iteration 517: Temperature = 16.2075, Current Cost = 26, Best Cost = 8
# Iteration 518: Temperature = 16.1812, Current Cost = 26, Best Cost = 8
# Iteration 519: Temperature = 16.1551, Current Cost = 26, Best Cost = 8
# Iteration 520: Temperature = 16.1290, Current Cost = 30, Best Cost = 8
# Iteration 521: Temperature = 16.1031, Current Cost = 28, Best Cost = 8
# Iteration 522: Temperature = 16.0772, Current Cost = 28, Best Cost = 8
# Iteration 523: Temperature = 16.0514, Current Cost = 32, Best Cost = 8
# Iteration 524: Temperature = 16.0256, Current Cost = 32, Best Cost = 8
# Iteration 525: Temperature = 16.0000, Current Cost = 28, Best Cost = 8
# Iteration 526: Temperature = 15.9744, Current Cost = 32, Best Cost = 8
# Iteration 527: Temperature = 15.9490, Current Cost = 32, Best Cost = 8
# Iteration 528: Temperature = 15.9236, Current Cost = 32, Best Cost = 8
# Iteration 529: Temperature = 15.8983, Current Cost = 32, Best Cost = 8
# Iteration 530: Temperature = 15.8730, Current Cost = 32, Best Cost = 8
# Iteration 531: Temperature = 15.8479, Current Cost = 32, Best Cost = 8
# Iteration 532: Temperature = 15.8228, Current Cost = 28, Best Cost = 8
# Iteration 533: Temperature = 15.7978, Current Cost = 32, Best Cost = 8
# Iteration 534: Temperature = 15.7729, Current Cost = 32, Best Cost = 8
# Iteration 535: Temperature = 15.7480, Current Cost = 32, Best Cost = 8
# Iteration 536: Temperature = 15.7233, Current Cost = 32, Best Cost = 8
# Iteration 537: Temperature = 15.6986, Current Cost = 34, Best Cost = 8
# Iteration 538: Temperature = 15.6740, Current Cost = 38, Best Cost = 8
# Iteration 539: Temperature = 15.6495, Current Cost = 38, Best Cost = 8
# Iteration 540: Temperature = 15.6250, Current Cost = 34, Best Cost = 8
# Iteration 541: Temperature = 15.6006, Current Cost = 38, Best Cost = 8
# Iteration 542: Temperature = 15.5763, Current Cost = 38, Best Cost = 8
# Iteration 543: Temperature = 15.5521, Current Cost = 38, Best Cost = 8
# Iteration 544: Temperature = 15.5280, Current Cost = 38, Best Cost = 8
# Iteration 545: Temperature = 15.5039, Current Cost = 42, Best Cost = 8
# Iteration 546: Temperature = 15.4799, Current Cost = 42, Best Cost = 8
# Iteration 547: Temperature = 15.4560, Current Cost = 42, Best Cost = 8
# Iteration 548: Temperature = 15.4321, Current Cost = 42, Best Cost = 8
# Iteration 549: Temperature = 15.4083, Current Cost = 46, Best Cost = 8
# Iteration 550: Temperature = 15.3846, Current Cost = 50, Best Cost = 8
# Iteration 551: Temperature = 15.3610, Current Cost = 54, Best Cost = 8
# Iteration 552: Temperature = 15.3374, Current Cost = 50, Best Cost = 8
# Iteration 553: Temperature = 15.3139, Current Cost = 50, Best Cost = 8
# Iteration 554: Temperature = 15.2905, Current Cost = 50, Best Cost = 8
# Iteration 555: Temperature = 15.2672, Current Cost = 50, Best Cost = 8
# Iteration 556: Temperature = 15.2439, Current Cost = 50, Best Cost = 8
# Iteration 557: Temperature = 15.2207, Current Cost = 50, Best Cost = 8
# Iteration 558: Temperature = 15.1976, Current Cost = 50, Best Cost = 8
# Iteration 559: Temperature = 15.1745, Current Cost = 50, Best Cost = 8
# Iteration 560: Temperature = 15.1515, Current Cost = 54, Best Cost = 8
# Iteration 561: Temperature = 15.1286, Current Cost = 54, Best Cost = 8
# Iteration 562: Temperature = 15.1057, Current Cost = 54, Best Cost = 8
# Iteration 563: Temperature = 15.0830, Current Cost = 50, Best Cost = 8
# Iteration 564: Temperature = 15.0602, Current Cost = 54, Best Cost = 8
# Iteration 565: Temperature = 15.0376, Current Cost = 54, Best Cost = 8
# Iteration 566: Temperature = 15.0150, Current Cost = 58, Best Cost = 8
# Iteration 567: Temperature = 14.9925, Current Cost = 58, Best Cost = 8
# Iteration 568: Temperature = 14.9701, Current Cost = 58, Best Cost = 8
# Iteration 569: Temperature = 14.9477, Current Cost = 58, Best Cost = 8
# Iteration 570: Temperature = 14.9254, Current Cost = 58, Best Cost = 8
# Iteration 571: Temperature = 14.9031, Current Cost = 58, Best Cost = 8
# Iteration 572: Temperature = 14.8810, Current Cost = 54, Best Cost = 8
# Iteration 573: Temperature = 14.8588, Current Cost = 50, Best Cost = 8
# Iteration 574: Temperature = 14.8368, Current Cost = 54, Best Cost = 8
# Iteration 575: Temperature = 14.8148, Current Cost = 54, Best Cost = 8
# Iteration 576: Temperature = 14.7929, Current Cost = 54, Best Cost = 8
# Iteration 577: Temperature = 14.7710, Current Cost = 54, Best Cost = 8
# Iteration 578: Temperature = 14.7493, Current Cost = 54, Best Cost = 8
# Iteration 579: Temperature = 14.7275, Current Cost = 54, Best Cost = 8
# Iteration 580: Temperature = 14.7059, Current Cost = 58, Best Cost = 8
# Iteration 581: Temperature = 14.6843, Current Cost = 54, Best Cost = 8
# Iteration 582: Temperature = 14.6628, Current Cost = 54, Best Cost = 8
# Iteration 583: Temperature = 14.6413, Current Cost = 54, Best Cost = 8
# Iteration 584: Temperature = 14.6199, Current Cost = 54, Best Cost = 8
# Iteration 585: Temperature = 14.5985, Current Cost = 54, Best Cost = 8
# Iteration 586: Temperature = 14.5773, Current Cost = 50, Best Cost = 8
# Iteration 587: Temperature = 14.5560, Current Cost = 54, Best Cost = 8
# Iteration 588: Temperature = 14.5349, Current Cost = 54, Best Cost = 8
# Iteration 589: Temperature = 14.5138, Current Cost = 50, Best Cost = 8
# Iteration 590: Temperature = 14.4928, Current Cost = 50, Best Cost = 8
# Iteration 591: Temperature = 14.4718, Current Cost = 50, Best Cost = 8
# Iteration 592: Temperature = 14.4509, Current Cost = 50, Best Cost = 8
# Iteration 593: Temperature = 14.4300, Current Cost = 46, Best Cost = 8
# Iteration 594: Temperature = 14.4092, Current Cost = 46, Best Cost = 8
# Iteration 595: Temperature = 14.3885, Current Cost = 46, Best Cost = 8
# Iteration 596: Temperature = 14.3678, Current Cost = 50, Best Cost = 8
# Iteration 597: Temperature = 14.3472, Current Cost = 50, Best Cost = 8
# Iteration 598: Temperature = 14.3266, Current Cost = 48, Best Cost = 8
# Iteration 599: Temperature = 14.3062, Current Cost = 48, Best Cost = 8
# Iteration 600: Temperature = 14.2857, Current Cost = 48, Best Cost = 8
# Iteration 601: Temperature = 14.2653, Current Cost = 48, Best Cost = 8
# Iteration 602: Temperature = 14.2450, Current Cost = 52, Best Cost = 8
# Iteration 603: Temperature = 14.2248, Current Cost = 52, Best Cost = 8
# Iteration 604: Temperature = 14.2045, Current Cost = 52, Best Cost = 8
# Iteration 605: Temperature = 14.1844, Current Cost = 52, Best Cost = 8
# Iteration 606: Temperature = 14.1643, Current Cost = 54, Best Cost = 8
# Iteration 607: Temperature = 14.1443, Current Cost = 58, Best Cost = 8
# Iteration 608: Temperature = 14.1243, Current Cost = 58, Best Cost = 8
# Iteration 609: Temperature = 14.1044, Current Cost = 62, Best Cost = 8
# Iteration 610: Temperature = 14.0845, Current Cost = 58, Best Cost = 8
# Iteration 611: Temperature = 14.0647, Current Cost = 58, Best Cost = 8
# Iteration 612: Temperature = 14.0449, Current Cost = 58, Best Cost = 8
# Iteration 613: Temperature = 14.0252, Current Cost = 54, Best Cost = 8
# Iteration 614: Temperature = 14.0056, Current Cost = 50, Best Cost = 8
# Iteration 615: Temperature = 13.9860, Current Cost = 46, Best Cost = 8
# Iteration 616: Temperature = 13.9665, Current Cost = 42, Best Cost = 8
# Iteration 617: Temperature = 13.9470, Current Cost = 42, Best Cost = 8
# Iteration 618: Temperature = 13.9276, Current Cost = 42, Best Cost = 8
# Iteration 619: Temperature = 13.9082, Current Cost = 46, Best Cost = 8
# Iteration 620: Temperature = 13.8889, Current Cost = 46, Best Cost = 8
# Iteration 621: Temperature = 13.8696, Current Cost = 46, Best Cost = 8
# Iteration 622: Temperature = 13.8504, Current Cost = 50, Best Cost = 8
# Iteration 623: Temperature = 13.8313, Current Cost = 50, Best Cost = 8
# Iteration 624: Temperature = 13.8122, Current Cost = 50, Best Cost = 8
# Iteration 625: Temperature = 13.7931, Current Cost = 54, Best Cost = 8
# Iteration 626: Temperature = 13.7741, Current Cost = 54, Best Cost = 8
# Iteration 627: Temperature = 13.7552, Current Cost = 50, Best Cost = 8
# Iteration 628: Temperature = 13.7363, Current Cost = 50, Best Cost = 8
# Iteration 629: Temperature = 13.7174, Current Cost = 50, Best Cost = 8
# Iteration 630: Temperature = 13.6986, Current Cost = 54, Best Cost = 8
# Iteration 631: Temperature = 13.6799, Current Cost = 54, Best Cost = 8
# Iteration 632: Temperature = 13.6612, Current Cost = 54, Best Cost = 8
# Iteration 633: Temperature = 13.6426, Current Cost = 54, Best Cost = 8
# Iteration 634: Temperature = 13.6240, Current Cost = 52, Best Cost = 8
# Iteration 635: Temperature = 13.6054, Current Cost = 52, Best Cost = 8
# Iteration 636: Temperature = 13.5870, Current Cost = 52, Best Cost = 8
# Iteration 637: Temperature = 13.5685, Current Cost = 52, Best Cost = 8
# Iteration 638: Temperature = 13.5501, Current Cost = 54, Best Cost = 8
# Iteration 639: Temperature = 13.5318, Current Cost = 54, Best Cost = 8
# Iteration 640: Temperature = 13.5135, Current Cost = 54, Best Cost = 8
# Iteration 641: Temperature = 13.4953, Current Cost = 52, Best Cost = 8
# Iteration 642: Temperature = 13.4771, Current Cost = 52, Best Cost = 8
# Iteration 643: Temperature = 13.4590, Current Cost = 48, Best Cost = 8
# Iteration 644: Temperature = 13.4409, Current Cost = 50, Best Cost = 8
# Iteration 645: Temperature = 13.4228, Current Cost = 50, Best Cost = 8
# Iteration 646: Temperature = 13.4048, Current Cost = 50, Best Cost = 8
# Iteration 647: Temperature = 13.3869, Current Cost = 50, Best Cost = 8
# Iteration 648: Temperature = 13.3690, Current Cost = 50, Best Cost = 8
# Iteration 649: Temperature = 13.3511, Current Cost = 50, Best Cost = 8
# Iteration 650: Temperature = 13.3333, Current Cost = 50, Best Cost = 8
# Iteration 651: Temperature = 13.3156, Current Cost = 46, Best Cost = 8
# Iteration 652: Temperature = 13.2979, Current Cost = 44, Best Cost = 8
# Iteration 653: Temperature = 13.2802, Current Cost = 44, Best Cost = 8
# Iteration 654: Temperature = 13.2626, Current Cost = 40, Best Cost = 8
# Iteration 655: Temperature = 13.2450, Current Cost = 40, Best Cost = 8
# Iteration 656: Temperature = 13.2275, Current Cost = 42, Best Cost = 8
# Iteration 657: Temperature = 13.2100, Current Cost = 42, Best Cost = 8
# Iteration 658: Temperature = 13.1926, Current Cost = 42, Best Cost = 8
# Iteration 659: Temperature = 13.1752, Current Cost = 42, Best Cost = 8
# Iteration 660: Temperature = 13.1579, Current Cost = 46, Best Cost = 8
# Iteration 661: Temperature = 13.1406, Current Cost = 46, Best Cost = 8
# Iteration 662: Temperature = 13.1234, Current Cost = 42, Best Cost = 8
# Iteration 663: Temperature = 13.1062, Current Cost = 46, Best Cost = 8
# Iteration 664: Temperature = 13.0890, Current Cost = 46, Best Cost = 8
# Iteration 665: Temperature = 13.0719, Current Cost = 44, Best Cost = 8
# Iteration 666: Temperature = 13.0548, Current Cost = 44, Best Cost = 8
# Iteration 667: Temperature = 13.0378, Current Cost = 40, Best Cost = 8
# Iteration 668: Temperature = 13.0208, Current Cost = 40, Best Cost = 8
# Iteration 669: Temperature = 13.0039, Current Cost = 36, Best Cost = 8
# Iteration 670: Temperature = 12.9870, Current Cost = 36, Best Cost = 8
# Iteration 671: Temperature = 12.9702, Current Cost = 36, Best Cost = 8
# Iteration 672: Temperature = 12.9534, Current Cost = 36, Best Cost = 8
# Iteration 673: Temperature = 12.9366, Current Cost = 32, Best Cost = 8
# Iteration 674: Temperature = 12.9199, Current Cost = 36, Best Cost = 8
# Iteration 675: Temperature = 12.9032, Current Cost = 36, Best Cost = 8
# Iteration 676: Temperature = 12.8866, Current Cost = 38, Best Cost = 8
# Iteration 677: Temperature = 12.8700, Current Cost = 38, Best Cost = 8
# ...
# Iteration 776: Temperature = 11.4155, Current Cost = 16, Best Cost = 8
# Iteration 777: Temperature = 11.4025, Current Cost = 16, Best Cost = 8
# Iteration 778: Temperature = 11.3895, Current Cost = 20, Best Cost = 8
# Iteration 779: Temperature = 11.3766, Current Cost = 22, Best Cost = 8
# Iteration 780: Temperature = 11.3636, Current Cost = 22, Best Cost = 8
# Iteration 781: Temperature = 11.3507, Current Cost = 22, Best Cost = 8
# Iteration 782: Temperature = 11.3379, Current Cost = 22, Best Cost = 8
# Iteration 783: Temperature = 11.3250, Current Cost = 22, Best Cost = 8
# Iteration 784: Temperature = 11.3122, Current Cost = 22, Best Cost = 8
# Iteration 785: Temperature = 11.2994, Current Cost = 26, Best Cost = 8
# Iteration 786: Temperature = 11.2867, Current Cost = 26, Best Cost = 8
# Iteration 787: Temperature = 11.2740, Current Cost = 26, Best Cost = 8
# Iteration 788: Temperature = 11.2613, Current Cost = 30, Best Cost = 8
# Iteration 789: Temperature = 11.2486, Current Cost = 34, Best Cost = 8
# Iteration 790: Temperature = 11.2360, Current Cost = 34, Best Cost = 8
# Iteration 791: Temperature = 11.2233, Current Cost = 38, Best Cost = 8
# Iteration 792: Temperature = 11.2108, Current Cost = 38, Best Cost = 8
# Iteration 793: Temperature = 11.1982, Current Cost = 42, Best Cost = 8
# Iteration 794: Temperature = 11.1857, Current Cost = 42, Best Cost = 8
# Iteration 795: Temperature = 11.1732, Current Cost = 42, Best Cost = 8
# Iteration 796: Temperature = 11.1607, Current Cost = 42, Best Cost = 8
# Iteration 797: Temperature = 11.1483, Current Cost = 38, Best Cost = 8
# Iteration 798: Temperature = 11.1359, Current Cost = 42, Best Cost = 8
# Iteration 799: Temperature = 11.1235, Current Cost = 38, Best Cost = 8
# Iteration 800: Temperature = 11.1111, Current Cost = 34, Best Cost = 8
# Iteration 801: Temperature = 11.0988, Current Cost = 34, Best Cost = 8
# Iteration 802: Temperature = 11.0865, Current Cost = 38, Best Cost = 8
# Iteration 803: Temperature = 11.0742, Current Cost = 42, Best Cost = 8
# Iteration 804: Temperature = 11.0619, Current Cost = 46, Best Cost = 8
# Iteration 805: Temperature = 11.0497, Current Cost = 46, Best Cost = 8
# Iteration 806: Temperature = 11.0375, Current Cost = 46, Best Cost = 8
# Iteration 807: Temperature = 11.0254, Current Cost = 42, Best Cost = 8
# Iteration 808: Temperature = 11.0132, Current Cost = 46, Best Cost = 8
# Iteration 809: Temperature = 11.0011, Current Cost = 46, Best Cost = 8
# Iteration 810: Temperature = 10.9890, Current Cost = 46, Best Cost = 8
# Iteration 811: Temperature = 10.9769, Current Cost = 46, Best Cost = 8
# Iteration 812: Temperature = 10.9649, Current Cost = 46, Best Cost = 8
# Iteration 813: Temperature = 10.9529, Current Cost = 46, Best Cost = 8
# Iteration 814: Temperature = 10.9409, Current Cost = 46, Best Cost = 8
# Iteration 815: Temperature = 10.9290, Current Cost = 42, Best Cost = 8
# Iteration 816: Temperature = 10.9170, Current Cost = 42, Best Cost = 8
# Iteration 817: Temperature = 10.9051, Current Cost = 42, Best Cost = 8
# Iteration 818: Temperature = 10.8932, Current Cost = 42, Best Cost = 8
# Iteration 819: Temperature = 10.8814, Current Cost = 38, Best Cost = 8
# Iteration 820: Temperature = 10.8696, Current Cost = 38, Best Cost = 8
# Iteration 821: Temperature = 10.8578, Current Cost = 38, Best Cost = 8
# Iteration 822: Temperature = 10.8460, Current Cost = 38, Best Cost = 8
# Iteration 823: Temperature = 10.8342, Current Cost = 38, Best Cost = 8
# Iteration 824: Temperature = 10.8225, Current Cost = 38, Best Cost = 8
# Iteration 825: Temperature = 10.8108, Current Cost = 38, Best Cost = 8
# Iteration 826: Temperature = 10.7991, Current Cost = 34, Best Cost = 8
# Iteration 827: Temperature = 10.7875, Current Cost = 38, Best Cost = 8
# Iteration 828: Temperature = 10.7759, Current Cost = 42, Best Cost = 8
# Iteration 829: Temperature = 10.7643, Current Cost = 42, Best Cost = 8
# Iteration 830: Temperature = 10.7527, Current Cost = 38, Best Cost = 8
# Iteration 831: Temperature = 10.7411, Current Cost = 38, Best Cost = 8
# Iteration 832: Temperature = 10.7296, Current Cost = 42, Best Cost = 8
# Iteration 833: Temperature = 10.7181, Current Cost = 42, Best Cost = 8
# Iteration 834: Temperature = 10.7066, Current Cost = 42, Best Cost = 8
# Iteration 835: Temperature = 10.6952, Current Cost = 46, Best Cost = 8
# Iteration 836: Temperature = 10.6838, Current Cost = 46, Best Cost = 8
# Iteration 837: Temperature = 10.6724, Current Cost = 42, Best Cost = 8
# Iteration 838: Temperature = 10.6610, Current Cost = 42, Best Cost = 8
# Iteration 839: Temperature = 10.6496, Current Cost = 42, Best Cost = 8
# Iteration 840: Temperature = 10.6383, Current Cost = 38, Best Cost = 8
# Iteration 841: Temperature = 10.6270, Current Cost = 42, Best Cost = 8
# Iteration 842: Temperature = 10.6157, Current Cost = 42, Best Cost = 8
# Iteration 843: Temperature = 10.6045, Current Cost = 42, Best Cost = 8
# Iteration 844: Temperature = 10.5932, Current Cost = 38, Best Cost = 8
# Iteration 845: Temperature = 10.5820, Current Cost = 38, Best Cost = 8
# Iteration 846: Temperature = 10.5708, Current Cost = 34, Best Cost = 8
# Iteration 847: Temperature = 10.5597, Current Cost = 30, Best Cost = 8
# Iteration 848: Temperature = 10.5485, Current Cost = 30, Best Cost = 8
# Iteration 849: Temperature = 10.5374, Current Cost = 30, Best Cost = 8
# Iteration 850: Temperature = 10.5263, Current Cost = 30, Best Cost = 8
# Iteration 851: Temperature = 10.5152, Current Cost = 26, Best Cost = 8
# Iteration 852: Temperature = 10.5042, Current Cost = 26, Best Cost = 8
# Iteration 853: Temperature = 10.4932, Current Cost = 26, Best Cost = 8
# Iteration 854: Temperature = 10.4822, Current Cost = 26, Best Cost = 8
# Iteration 855: Temperature = 10.4712, Current Cost = 30, Best Cost = 8
# Iteration 856: Temperature = 10.4603, Current Cost = 30, Best Cost = 8
# Iteration 857: Temperature = 10.4493, Current Cost = 30, Best Cost = 8
# Iteration 858: Temperature = 10.4384, Current Cost = 34, Best Cost = 8
# Iteration 859: Temperature = 10.4275, Current Cost = 34, Best Cost = 8
# Iteration 860: Temperature = 10.4167, Current Cost = 34, Best Cost = 8
# Iteration 861: Temperature = 10.4058, Current Cost = 30, Best Cost = 8
# Iteration 862: Temperature = 10.3950, Current Cost = 34, Best Cost = 8
# Iteration 863: Temperature = 10.3842, Current Cost = 38, Best Cost = 8
# Iteration 864: Temperature = 10.3734, Current Cost = 38, Best Cost = 8
# Iteration 865: Temperature = 10.3627, Current Cost = 42, Best Cost = 8
# Iteration 866: Temperature = 10.3520, Current Cost = 42, Best Cost = 8
# Iteration 867: Temperature = 10.3413, Current Cost = 42, Best Cost = 8
# Iteration 868: Temperature = 10.3306, Current Cost = 38, Best Cost = 8
# Iteration 869: Temperature = 10.3199, Current Cost = 38, Best Cost = 8
# Iteration 870: Temperature = 10.3093, Current Cost = 42, Best Cost = 8
# Iteration 871: Temperature = 10.2987, Current Cost = 38, Best Cost = 8
# Iteration 872: Temperature = 10.2881, Current Cost = 42, Best Cost = 8
# Iteration 873: Temperature = 10.2775, Current Cost = 46, Best Cost = 8
# Iteration 874: Temperature = 10.2669, Current Cost = 46, Best Cost = 8
# Iteration 875: Temperature = 10.2564, Current Cost = 46, Best Cost = 8
# Iteration 876: Temperature = 10.2459, Current Cost = 50, Best Cost = 8
# Iteration 877: Temperature = 10.2354, Current Cost = 46, Best Cost = 8
# Iteration 878: Temperature = 10.2249, Current Cost = 46, Best Cost = 8
# Iteration 879: Temperature = 10.2145, Current Cost = 46, Best Cost = 8
# Iteration 880: Temperature = 10.2041, Current Cost = 42, Best Cost = 8
# Iteration 881: Temperature = 10.1937, Current Cost = 40, Best Cost = 8
# Iteration 882: Temperature = 10.1833, Current Cost = 44, Best Cost = 8
# Iteration 883: Temperature = 10.1729, Current Cost = 40, Best Cost = 8
# Iteration 884: Temperature = 10.1626, Current Cost = 40, Best Cost = 8
# Iteration 885: Temperature = 10.1523, Current Cost = 40, Best Cost = 8
# Iteration 886: Temperature = 10.1420, Current Cost = 44, Best Cost = 8
# Iteration 887: Temperature = 10.1317, Current Cost = 44, Best Cost = 8
# Iteration 888: Temperature = 10.1215, Current Cost = 44, Best Cost = 8
# Iteration 889: Temperature = 10.1112, Current Cost = 46, Best Cost = 8
# Iteration 890: Temperature = 10.1010, Current Cost = 50, Best Cost = 8
# Iteration 891: Temperature = 10.0908, Current Cost = 54, Best Cost = 8
# Iteration 892: Temperature = 10.0806, Current Cost = 50, Best Cost = 8
# Iteration 893: Temperature = 10.0705, Current Cost = 50, Best Cost = 8
# Iteration 894: Temperature = 10.0604, Current Cost = 50, Best Cost = 8
# Iteration 895: Temperature = 10.0503, Current Cost = 50, Best Cost = 8
# Iteration 896: Temperature = 10.0402, Current Cost = 50, Best Cost = 8
# Iteration 897: Temperature = 10.0301, Current Cost = 50, Best Cost = 8
# Iteration 898: Temperature = 10.0200, Current Cost = 50, Best Cost = 8
# Iteration 899: Temperature = 10.0100, Current Cost = 46, Best Cost = 8
# Iteration 900: Temperature = 10.0000, Current Cost = 44, Best Cost = 8
# Iteration 901: Temperature = 9.9900, Current Cost = 44, Best Cost = 8
# Iteration 902: Temperature = 9.9800, Current Cost = 48, Best Cost = 8
# Iteration 903: Temperature = 9.9701, Current Cost = 48, Best Cost = 8
# Iteration 904: Temperature = 9.9602, Current Cost = 44, Best Cost = 8
# Iteration 905: Temperature = 9.9502, Current Cost = 44, Best Cost = 8
# Iteration 906: Temperature = 9.9404, Current Cost = 40, Best Cost = 8
# Iteration 907: Temperature = 9.9305, Current Cost = 40, Best Cost = 8
# Iteration 908: Temperature = 9.9206, Current Cost = 42, Best Cost = 8
# Iteration 909: Temperature = 9.9108, Current Cost = 40, Best Cost = 8
# Iteration 910: Temperature = 9.9010, Current Cost = 40, Best Cost = 8
# Iteration 911: Temperature = 9.8912, Current Cost = 44, Best Cost = 8
# Iteration 912: Temperature = 9.8814, Current Cost = 44, Best Cost = 8
# Iteration 913: Temperature = 9.8717, Current Cost = 44, Best Cost = 8
# Iteration 914: Temperature = 9.8619, Current Cost = 46, Best Cost = 8
# Iteration 915: Temperature = 9.8522, Current Cost = 46, Best Cost = 8
# Iteration 916: Temperature = 9.8425, Current Cost = 44, Best Cost = 8
# Iteration 917: Temperature = 9.8328, Current Cost = 46, Best Cost = 8
# Iteration 918: Temperature = 9.8232, Current Cost = 46, Best Cost = 8
# Iteration 919: Temperature = 9.8135, Current Cost = 46, Best Cost = 8
# Iteration 920: Temperature = 9.8039, Current Cost = 46, Best Cost = 8
# Iteration 921: Temperature = 9.7943, Current Cost = 44, Best Cost = 8
# Iteration 922: Temperature = 9.7847, Current Cost = 44, Best Cost = 8
# Iteration 923: Temperature = 9.7752, Current Cost = 40, Best Cost = 8
# Iteration 924: Temperature = 9.7656, Current Cost = 40, Best Cost = 8
# Iteration 925: Temperature = 9.7561, Current Cost = 36, Best Cost = 8
# Iteration 926: Temperature = 9.7466, Current Cost = 40, Best Cost = 8
# Iteration 927: Temperature = 9.7371, Current Cost = 36, Best Cost = 8
# Iteration 928: Temperature = 9.7276, Current Cost = 40, Best Cost = 8
# Iteration 929: Temperature = 9.7182, Current Cost = 40, Best Cost = 8
# Iteration 930: Temperature = 9.7087, Current Cost = 40, Best Cost = 8
# Iteration 931: Temperature = 9.6993, Current Cost = 40, Best Cost = 8
# Iteration 932: Temperature = 9.6899, Current Cost = 36, Best Cost = 8
# Iteration 933: Temperature = 9.6805, Current Cost = 36, Best Cost = 8
# Iteration 934: Temperature = 9.6712, Current Cost = 36, Best Cost = 8
# Iteration 935: Temperature = 9.6618, Current Cost = 36, Best Cost = 8
# Iteration 936: Temperature = 9.6525, Current Cost = 36, Best Cost = 8
# Iteration 937: Temperature = 9.6432, Current Cost = 36, Best Cost = 8
# Iteration 938: Temperature = 9.6339, Current Cost = 40, Best Cost = 8
# Iteration 939: Temperature = 9.6246, Current Cost = 40, Best Cost = 8
# Iteration 940: Temperature = 9.6154, Current Cost = 36, Best Cost = 8
# Iteration 941: Temperature = 9.6061, Current Cost = 40, Best Cost = 8
# Iteration 942: Temperature = 9.5969, Current Cost = 40, Best Cost = 8
# Iteration 943: Temperature = 9.5877, Current Cost = 40, Best Cost = 8
# Iteration 944: Temperature = 9.5785, Current Cost = 40, Best Cost = 8
# Iteration 945: Temperature = 9.5694, Current Cost = 44, Best Cost = 8
# Iteration 946: Temperature = 9.5602, Current Cost = 40, Best Cost = 8
# Iteration 947: Temperature = 9.5511, Current Cost = 40, Best Cost = 8
# Iteration 948: Temperature = 9.5420, Current Cost = 40, Best Cost = 8
# Iteration 949: Temperature = 9.5329, Current Cost = 40, Best Cost = 8
# Iteration 950: Temperature = 9.5238, Current Cost = 42, Best Cost = 8
# Iteration 951: Temperature = 9.5147, Current Cost = 42, Best Cost = 8
# Iteration 952: Temperature = 9.5057, Current Cost = 42, Best Cost = 8
# Iteration 953: Temperature = 9.4967, Current Cost = 38, Best Cost = 8
# Iteration 954: Temperature = 9.4877, Current Cost = 38, Best Cost = 8
# Iteration 955: Temperature = 9.4787, Current Cost = 38, Best Cost = 8
# Iteration 956: Temperature = 9.4697, Current Cost = 38, Best Cost = 8
# Iteration 957: Temperature = 9.4607, Current Cost = 34, Best Cost = 8
# Iteration 958: Temperature = 9.4518, Current Cost = 30, Best Cost = 8
# Iteration 959: Temperature = 9.4429, Current Cost = 26, Best Cost = 8
# Iteration 960: Temperature = 9.4340, Current Cost = 26, Best Cost = 8
# Iteration 961: Temperature = 9.4251, Current Cost = 24, Best Cost = 8
# Iteration 962: Temperature = 9.4162, Current Cost = 28, Best Cost = 8
# Iteration 963: Temperature = 9.4073, Current Cost = 28, Best Cost = 8
# Iteration 964: Temperature = 9.3985, Current Cost = 28, Best Cost = 8
# Iteration 965: Temperature = 9.3897, Current Cost = 28, Best Cost = 8
# Iteration 966: Temperature = 9.3809, Current Cost = 28, Best Cost = 8
# Iteration 967: Temperature = 9.3721, Current Cost = 30, Best Cost = 8
# Iteration 968: Temperature = 9.3633, Current Cost = 28, Best Cost = 8
# Iteration 969: Temperature = 9.3545, Current Cost = 28, Best Cost = 8
# Iteration 970: Temperature = 9.3458, Current Cost = 28, Best Cost = 8
# Iteration 971: Temperature = 9.3371, Current Cost = 30, Best Cost = 8
# Iteration 972: Temperature = 9.3284, Current Cost = 26, Best Cost = 8
# Iteration 973: Temperature = 9.3197, Current Cost = 30, Best Cost = 8
# Iteration 974: Temperature = 9.3110, Current Cost = 28, Best Cost = 8
# Iteration 975: Temperature = 9.3023, Current Cost = 28, Best Cost = 8
# Iteration 976: Temperature = 9.2937, Current Cost = 28, Best Cost = 8
# Iteration 977: Temperature = 9.2851, Current Cost = 28, Best Cost = 8
# Iteration 978: Temperature = 9.2764, Current Cost = 28, Best Cost = 8
# Iteration 979: Temperature = 9.2678, Current Cost = 28, Best Cost = 8
# Iteration 980: Temperature = 9.2593, Current Cost = 28, Best Cost = 8
# Iteration 981: Temperature = 9.2507, Current Cost = 24, Best Cost = 8
# Iteration 982: Temperature = 9.2421, Current Cost = 24, Best Cost = 8
# Iteration 983: Temperature = 9.2336, Current Cost = 24, Best Cost = 8
# Iteration 984: Temperature = 9.2251, Current Cost = 24, Best Cost = 8
# Iteration 985: Temperature = 9.2166, Current Cost = 24, Best Cost = 8
# Iteration 986: Temperature = 9.2081, Current Cost = 24, Best Cost = 8
# Iteration 987: Temperature = 9.1996, Current Cost = 24, Best Cost = 8
# Iteration 988: Temperature = 9.1912, Current Cost = 24, Best Cost = 8
# Iteration 989: Temperature = 9.1827, Current Cost = 24, Best Cost = 8
# Iteration 990: Temperature = 9.1743, Current Cost = 24, Best Cost = 8
# Iteration 991: Temperature = 9.1659, Current Cost = 24, Best Cost = 8
# Iteration 992: Temperature = 9.1575, Current Cost = 26, Best Cost = 8
# Iteration 993: Temperature = 9.1491, Current Cost = 26, Best Cost = 8
# Iteration 994: Temperature = 9.1408, Current Cost = 22, Best Cost = 8
# Iteration 995: Temperature = 9.1324, Current Cost = 18, Best Cost = 8
# Iteration 996: Temperature = 9.1241, Current Cost = 22, Best Cost = 8
# Iteration 997: Temperature = 9.1158, Current Cost = 18, Best Cost = 8
# Iteration 998: Temperature = 9.1075, Current Cost = 18, Best Cost = 8
# Iteration 999: Temperature = 9.0992, Current Cost = 16, Best Cost = 8
# Iteration 1000: Temperature = 9.0909, Current Cost = 16, Best Cost = 8
# Initial Hospitals: [(3, 4), (3, 4)]
# Best Hospitals: [(2, 2), (4, 6)]
# Total Cost: 8

# %% [markdown]
# The algorithm takes as input a problem and *max*, the number of times it
# should repeat itself. For each iteration, *T* is set using a Temperature
# function. This function return a higher value in the early iterations
# (when *t* is low) and a lower value in later iterations (when *t* is
# high). Then, a random neighbor is selected, and *ΔE* is computed such
# that it quantifies how better the neighbor state is than the current
# state. If the neighbor state is better than the current state (*ΔE* \>
# 0), as before, we set our current state to be the neighbor state.
# However, when the neighbor state is worse (*ΔE* \< 0), we still might
# set our current state to be that neighbor state, and we do so with
# probability e^(*ΔE/T*). The idea here is that a more negative *ΔE* will
# result in lower probability of the neighbor state being chosen, and the
# higher the temperature *T* the higher the probability that the neighbor
# state will be chosen. This means that the worse the neighbor state, the
# less likely it is to be chosen, and the earlier the algorithm is in its
# process, the more likely it is to set a worse neighbor state as current
# state. The math behind this is as follows: e is a constant (around
# 2.72), and *ΔE* is negative (since this neighbor is worse than the
# current state). The more negative *ΔE*, the closer the resulting value
# to 0. The higher the temperature *T* is, the closer *ΔE/T* is to 0,
# making the probability closer to 1.

# %% [markdown]
# ### Traveling Salesman Problem
#
# In the traveling salesman problem, the task is to connect all points
# while choosing the shortest possible distance. This is, for example,
# what delivery companies need to do: find the shortest route from the
# store to all the customers’ houses and back.
#
# ![Traveling Salesman Problem](https://cs50.harvard.edu/ai/2020/notes/3/travelingsalesman.png)
#
# In this case, a neighbor state might be seen as a state where two arrows
# swap places. Calculating every possible combination makes this problem
# computationally demanding (having just 10 points gives us 10!, or
# 3,628,800 possible routes). By using the simulated annealing algorithm,
# a good solution can be found for a lower computational cost.

# %% [markdown]
# ## Linear Programming
#
# Linear programming is a family of problems that optimize a linear
# equation (an equation of the form y = ax₁ + bx₂ + …).
#
# Linear programming will have the following components:
#
# - A cost function that we want to minimize:
#     c₁x₁ + c₂x₂ + … + cₙxₙ. Here, each x₋ is a variable and it is
#     associated with some cost c₋.
# - A constraint that’s represented as a sum
#     of variables that is either less than or equal to a value (a₁x₁ +
#     a₂x₂ + … + aₙxₙ ≤ b) or precisely equal to this value (a₁x₁ + a₂x₂ +
#     … + aₙxₙ = b). In this case, x₋ is a variable, and a₋ is some
#     resource associated with it, and b is how much resources we can
#     dedicate to this problem.
# - Individual bounds on variables (for
#     example, that a variable can’t be negative) of the form lᵢ ≤ xᵢ ≤
#     uᵢ.
#
# Consider the following example:
#
# - Two machines, X₁ and X₂. X₁ costs
#     $50/hour to run, X₂ costs $80/hour to run. The goal is to minimize
#     cost. This can be formalized as a cost function: 50x₁ + 80x₂.
# - X₁ requires 5 units of labor per hour. X₂
#     requires 2 units of labor per hour. Total of 20 units of labor to
#     spend. This can be formalized as a constraint: 5x₁ + 2x₂ ≤ 20.
# - X₁ produces 10 units of output per hour.
#     X₂ produces 12 units of output per hour. Company needs 90 units of
#     output. This is another constraint. Literally, it can be rewritten
#     as 10x₁ + 12x₂ ≥ 90. However, constraints need to be of the form
#     (a₁x₁ + a₂x₂ + … + aₙxₙ ≤ b) or (a₁x₁ + a₂x₂ + … + aₙxₙ = b).
#     Therefore, we multiply by (-1) to get to an equivalent equation of
#     the desired form: (-10x₁) + (-12x₂) ≤ -90.
#
# An optimizing algorithm for linear programming requires background
# knowledge in geometry and linear algebra that we don’t want to assume.
# Instead, we can use algorithms that already exist, such as Simplex and
# Interior-Point.
#
# The following is a linear programming example that uses the scipy
# library in Python:

# %%
import scipy.optimize

# Objective Function: 50x_1 + 80x_2
# Constraint 1: 5x_1 + 2x_2 <= 20
# Constraint 2: -10x_1 + -12x_2 <= -90

result = scipy.optimize.linprog(
    [50, 80],  # Cost function: 50x_1 + 80x_2
    A_ub=[[5, 2], [-10, -12]],  # Coefficients for inequalities
    b_ub=[20, -90],  # Constraints for inequalities: 20 and -90
)

if result.success:
    print(f"X1: {round(result.x[0], 2)} hours")
    print(f"X2: {round(result.x[1], 2)} hours")
else:
    print("No solution")
# Out:
# X1: 1.5 hours
# X2: 6.25 hours

# %% [markdown]
# ## Constraint Satisfaction
#
# Constraint Satisfaction problems are a class of problems where variables
# need to be assigned values while satisfying some conditions.
#
# Constraints satisfaction problems have the following properties:
#
# - Set of variables (x₁, x₂, …, xₙ)
# - Set of domains for each variable {D₁, D₂,
#     …, Dₙ}
# - Set of constraints C
#
# Sudoku can be represented as a constraint satisfaction problem, where
# each empty square is a variable, the domain is the numbers 1-9, and the
# constraints are the squares that can’t be equal to each other.
#
# Consider another example. Each of students 1-4 is taking three courses
# from A, B, …, G. Each course needs to have an exam, and the possible
# days for exams are Monday, Tuesday, and Wednesday. However, the same
# student can’t have two exams on the same day. In this case, the
# variables are the courses, the domain is the days, and the constraints
# are which courses can’t be scheduled to have an exam on the same day
# because the same student is taking them. This can be visualized as
# follows:
#
# ![Constraint Satisfaction Setting](https://cs50.harvard.edu/ai/2020/notes/3/constraintsatisfaction1.png)
#
# This problem can be solved using constraints that are represented as a
# graph. Each node on the graph is a course, and an edge is drawn between
# two courses if they can’t be scheduled on the same day. In this case,
# the graph will look this:
#
# ![Constraint Satisfaction Constraints](https://cs50.harvard.edu/ai/2020/notes/3/constraintsatisfaction2.png)
#
# A few more terms worth knowing about constraint satisfaction problems:
#
# - A **Hard Constraint** is a constraint
#     that must be satisfied in a correct solution.
# - A **Soft Constraint** is a constraint
#     that expresses which solution is preferred over others.
# - A **Unary Constraint** is a constraint
#     that involves only one variable. In our example, a unary constraint
#     would be saying that course A can’t have an exam on Monday {*A ≠
#     Monday*}.
# - A **Binary Constraint** is a constraint
#     that involves two variables. This is the type of constraint that we
#     used in the example above, saying that some two courses can’t have
#     the same value {*A ≠ B*}.

# %% [markdown]
# ## Node Consistency
#
# Node consistency is when all the values in a variable’s domain satisfy
# the variable’s unary constraints.
#
# For example, let’s take two courses, A and B. The domain for each course
# is {*Monday, Tuesday, Wednesday*}, and the constraints are {*A ≠ Mon, B
# ≠ Tue, B ≠ Mon, A ≠ B*}. Now, neither A nor B is consistent, because the
# existing constraints prevent them from being able to take every value
# that’s in their domain. However, if we remove Monday from A’s domain,
# then it will have node consistency. To achieve node consistency in B, we
# will have to remove both Monday and Tuesday from its domain.

# %% [markdown]
# ## Arc Consistency
#
# Arc consistency is when all the values in a variable’s domain satisfy
# the variable’s binary constraints (note that we are now using “arc” to
# refer to what we previously referred to as “edge”). In other words, to
# make X arc-consistent with respect to Y, remove elements from X’s domain
# until every choice for X has a possible choice for Y.
#
# Consider our previous example with the revised domains: A:{*Tuesday,
# Wednesday*} and B:{*Wednesday*}. For A to be arc-consistent with B, no
# matter what day A’s exam gets scheduled (from its domain), B will still
# be able to schedule an exam. Is A arc-consistent with B? If A takes the
# value Tuesday, then B can take the value Wednesday. However, if A takes
# the value Wednesday, then there is no value that B can take (remember
# that one of the constraints is A ≠ B). Therefore, A is not
# arc-consistent with B. To change this, we can remove Wednesday from A’s
# domain. Then, any value that A takes (Tuesday being the only option)
# leaves a value for B to take (Wednesday). Now, A is arc-consistent with
# B. Let’s look at an algorithm in pseudocode that makes a variable
# arc-consistent with respect to some other variable (note that csp stands
# for “constraint satisfaction problem”).
#
# function Revise(*csp, X, Y*):
#
# - *revised* = *false*
# - for *x* in *X.domain*:
#   - if no *y* in *Y.domain* satisfies constraint for (*X,Y*):
#     - delete *x* from *X.domain*
#     - *revised* = true
# - return *revised*

# %%
class CSP:
    def __init__(self, variables, domains, constraints):
        self.variables = variables
        self.domains = domains
        self.constraints = constraints

    def is_consistent(self, var, value, assignment):
        for constraint in self.constraints:
            if constraint[0] == var or constraint[1] == var:
                other_var = constraint[1] if constraint[0] == var else constraint[0]
                if other_var in assignment and not self.constraints[constraint](value, assignment[other_var]):
                    return False
        return True

    def revise(self, X, Y):
        revised = False
        for x in self.domains[X][:]:
            if not any(self.constraints[(X, Y)](x, y) for y in self.domains[Y]):
                self.domains[X].remove(x)
                revised = True
        return revised

# Example problem setup
variables = ['A', 'B']
domains = {
    'A': ['Monday', 'Tuesday', 'Wednesday'],
    'B': ['Monday', 'Tuesday', 'Wednesday']
}
constraints = {
    ('A', 'B'): lambda a, b: a != b
}

csp = CSP(variables, domains, constraints)

# Apply unary constraints
csp.domains['A'].remove('Monday')
csp.domains['B'].remove('Monday')
csp.domains['B'].remove('Tuesday')

print("Domains before revision:")
print(csp.domains)

# Revise domains to ensure arc consistency
csp.revise('A', 'B')

print("Domains after revision:")
print(csp.domains)
# Out:
# Domains before revision:
# {'A': ['Tuesday', 'Wednesday'], 'B': ['Wednesday']}
# Domains after revision:
# {'A': ['Tuesday'], 'B': ['Wednesday']}

# %% [markdown]
# This algorithm starts with tracking whether any change was made to X’s
# domain, using the variable *revised*. This will be useful in the next
# algorithm we examine. Then, the code repeats for every value in X’s
# domain and sees if Y has a value that satisfies the constraints. If yes,
# then do nothing, if not, remove this value from X’s domain.

# %% [markdown]
# Often we are interested in making the whole problem arc-consistent and
# not just one variable with respect to another. In this case, we will use
# an algorithm called AC-3, which uses Revise:
#
# function AC-3(*csp*):
#
# - *queue* = all arcs in *csp*
# - while *queue* non-empty:
#   - (*X, Y*) = Dequeue(*queue*)
#   - if Revise(*csp, X, Y*):
#     - if size of *X*.domain == 0:
#       - return *false*
#     - for each *Z* in *X*.neighbors -
#             {*Y*}:
#       - Enqueue(queue, (*Z,X*))
# - return true

# %%
class CSP:
    def __init__(self, variables, domains, neighbors, constraints):
        self.variables = variables
        self.domains = domains
        self.neighbors = neighbors
        self.constraints = constraints

    def is_consistent(self, var, value, assignment):
        for constraint in self.constraints:
            if constraint[0] == var or constraint[1] == var:
                other_var = constraint[1] if constraint[0] == var else constraint[0]
                if other_var in assignment and not self.constraints[constraint](value, assignment[other_var]):
                    return False
        return True

    def revise(self, X, Y):
        revised = False
        for x in self.domains[X][:]:
            if not any(self.constraints[(X, Y)](x, y) for y in self.domains[Y]):
                self.domains[X].remove(x)
                revised = True
        return revised

    def ac3(self):
        queue = [(X, Y) for X in self.variables for Y in self.neighbors[X]]
        while queue:
            (X, Y) = queue.pop(0)
            if self.revise(X, Y):
                if not self.domains[X]:
                    return False
                for Z in self.neighbors[X]:
                    if Z != Y:
                        queue.append((Z, X))
        return True

# Example problem setup
variables = ['A', 'B', 'C']
domains = {
    'A': ['Monday', 'Tuesday', 'Wednesday'],
    'B': ['Monday', 'Tuesday', 'Wednesday'],
    'C': ['Monday', 'Tuesday', 'Wednesday']
}
neighbors = {
    'A': ['B', 'C'],
    'B': ['A', 'C'],
    'C': ['A', 'B']
}
constraints = {
    ('A', 'B'): lambda a, b: a != b,
    ('A', 'C'): lambda a, c: a != c,
    ('B', 'C'): lambda b, c: b != c,
    ('B', 'A'): lambda b, a: b != a,
    ('C', 'A'): lambda c, a: c != a,
    ('C', 'B'): lambda c, b: c != b
}

csp = CSP(variables, domains, neighbors, constraints)

# Apply unary constraints
csp.domains['A'].remove('Monday')
csp.domains['B'].remove('Monday')
csp.domains['B'].remove('Tuesday')

print("Domains before AC-3:")
print(csp.domains)

# Run AC-3 algorithm to ensure arc consistency
if csp.ac3():
    print("Domains after AC-3:")
    print(csp.domains)
else:
    print("AC-3 failed: no solution possible")
# Out:
# Domains before AC-3:
# {'A': ['Tuesday', 'Wednesday'], 'B': ['Wednesday'], 'C': ['Monday', 'Tuesday', 'Wednesday']}
# Domains after AC-3:
# {'A': ['Tuesday'], 'B': ['Wednesday'], 'C': ['Monday']}

# %% [markdown]
# This algorithm adds all the arcs in the problem to a queue. Each time it
# considers an arc, it removes it from the queue. Then, it runs the Revise
# algorithm to see if this arc is consistent. If changes were made to make
# it consistent, further actions are needed. If the resulting domain of X
# is empty, it means that this constraint satisfaction problem is
# unsolvable (since there are no values that X can take that will allow Y
# to take any value given the constraints). If the problem is not deemed
# unsolvable in the previous step, then, since X’s domain was changed, we
# need to see if all the arcs associated with X are still consistent. That
# is, we take all of X’s neighbors except Y, and we add the arcs between
# them and X to the queue. However, if the Revise algorithm returns false,
# meaning that the domain wasn’t changed, we simply continue considering
# the other arcs.
#
# While the algorithm for arc consistency can simplify the problem, it
# will not necessarily solve it, since it considers binary constraints
# only and not how multiple nodes might be interconnected. Our previous
# example, where each of 4 students is taking 3 courses, remains unchanged
# by running AC-3 on it.

# %% [markdown]
# We have encountered search problems in our first lecture. A constraint
# satisfaction problem can be seen as a search problem:
#
# - Initial state: empty assignment (all
#     variables don’t have any values assigned to them).
# - Actions: add a {*variable = value*} to
#     assignment; that is, give some variable a value.
# - Transition model: shows how adding the
#     assignment changes the assignment. There is not much depth to this:
#     the transition model returns the state that includes the assignment
#     following the latest action.
# - Goal test: check if all variables are
#     assigned a value and all constraints are satisfied.
# - Path cost function: all paths have the
#     same cost. As we mentioned earlier, as opposed to typical search
#     problems, optimization problems care about the solution and not the
#     route to the solution.
#
# However, going about a constraint satisfaction problem naively, as a
# regular search problem, is massively inefficient. Instead, we can make
# use of the structure of a constraint satisfaction problem to solve it
# more efficiently.

# %% [markdown]
# ## Backtracking Search
#
# Backtracking search is a type of a search algorithm that takes into
# account the structure of a constraint satisfaction search problem. In
# general, it is a recursive function that attempts to continue assigning
# values as long as they satisfy the constraints. If constraints are
# violated, it tries a different assignment. Let’s look at the pseudocode
# for it:
#
# function Backtrack(*assignment, csp*):
#
# - if *assignment* complete:
#   - return *assignment*
# - *var* =
#     Select-Unassigned-Var(*assignment, csp*)
# - for *value* in Domain-Values(*var,
#     assignment, csp*):
#   - if *value* consistent with
#         *assignment*:
#     - add {*var = value*} to
#             *assignment*
#     - *result* = Backtrack(*assignment,
#             csp*)
#     - if *result* ≠ *failure*:
#       - return *result*
#     - *remove* {*var = value*} from
#             *assignment*
# - return failure
# In words, this algorithm starts with returning the current assignment if
# it is complete. This means that, if the algorithm is done, it will not
# perform any of the additional actions. Instead, it will just return the
# completed assignment. If the assignment is not complete, the algorithm
# selects any of the variables that do not have an assignment yet. Then,
# the algorithm tries to assign a value to the variable, and runs the
# Backtrack algorithm again on the resulting assignment (recursion). Then,
# it checks the resulting value. If it is not *failure*, it means that the
# assignment worked out, and it should return this assignment. If the
# resulting value is *failure*, then the latest assignment is removed, and
# a new possible value is attempted, repeating the same process. If all
# possible values in the domain returned *failure*, this means that we
# need to backtrack. That is, that the problem is with some previous
# assignment. If this happens with the variable we start with, then it
# means that no solution satisfies the constraints.
#
# Consider the following course of action:
#
# ![Backtracking Example](https://cs50.harvard.edu/ai/2020/notes/3/backtracking.png)
#
# We start with empty assignments (top left). Then, we choose the variable
# A, and assign to it some value, Monday (top right). Then, using this
# assignment, we run the algorithm again. Now that A already has an
# assignment, the algorithm will consider B, and assign Monday to it
# (bottom left). This assignment returns false, so instead of assigning a
# value to C given the previous assignment, the algorithm will try to
# assign a new value to B, Tuesday (bottom right). This new assignment
# satisfies the constraints, and a new variable will be considered next
# given this assignment. If, for example, assigning also Tuesday or
# Wednesday to B would bring to a failure, then the algorithm would
# backtrack and return to considering A, assigning another value to it,
# Tuesday. If also Tuesday and Wednesday return *failure*, then it means
# we have tried every possible assignment and the problem is unsolvable.
#
# In the source code section, you can find an implementation from scratch
# of the backtrack algorithm. However, this algorithm is widely used, and,
# as such, multiple libraries already contain an implementation of it.

# %%
"""
Naive backtracking search without any heuristics or inference.
"""

VARIABLES = ["A", "B", "C", "D", "E", "F", "G"]
CONSTRAINTS = [
    ("A", "B"),
    ("A", "C"),
    ("B", "C"),
    ("B", "D"),
    ("B", "E"),
    ("C", "E"),
    ("C", "F"),
    ("D", "E"),
    ("E", "F"),
    ("E", "G"),
    ("F", "G"),
]


def backtrack(assignment):
    """Runs backtracking search to find an assignment."""

    # Check if assignment is complete
    if len(assignment) == len(VARIABLES):
        return assignment

    # Try a new variable
    var = select_unassigned_variable(assignment)
    for value in ["Monday", "Tuesday", "Wednesday"]:
        new_assignment = assignment.copy()
        new_assignment[var] = value
        if consistent(new_assignment):
            result = backtrack(new_assignment)
            if result is not None:
                return result
    return None


def select_unassigned_variable(assignment):
    """Chooses a variable not yet assigned, in order."""
    for variable in VARIABLES:
        if variable not in assignment:
            return variable
    return None


def consistent(assignment):
    """Checks to see if an assignment is consistent."""
    for x, y in CONSTRAINTS:

        # Only consider arcs where both are assigned
        if x not in assignment or y not in assignment:
            continue

        # If both have same value, then not consistent
        if assignment[x] == assignment[y]:
            return False

    # If nothing inconsistent, then assignment is consistent
    return True


solution = backtrack({})
print(solution)
# Out:
# {'A': 'Monday', 'B': 'Tuesday', 'C': 'Wednesday', 'D': 'Wednesday', 'E': 'Monday', 'F': 'Tuesday', 'G': 'Wednesday'}

# %% [markdown]
# ### Inference
#
# Although backtracking search is more efficient than simple search, it
# still takes a lot of computational power. Enforcing arc consistency, on
# the other hand, is less resource intensive. By interleaving backtracking
# search with inference (enforcing arc consistency), we can get at a more
# efficient algorithm. This algorithm is called the **Maintaining
# Arc-Consistency** algorithm. This algorithm will enforce arc-consistency
# after every new assignment of the backtracking search. Specifically,
# after we make a new assignment to X, we will call the AC-3 algorithm and
# start it with a queue of all arcs (*Y,X*) where Y is a neighbor of X
# (and not a queue of all arcs in the problem). Following is a revised
# Backtrack algorithm that maintains arc-consistency, with the new
# additions in **bold**.
#
# function Backtrack(*assignment, csp*):
#
# - if *assignment* complete:
#   - return *assignment*
# - *var* =
#     Select-Unassigned-Var(*assignment, csp*)
# - for *value* in Domain-Values(*var,
#     assignment, csp*):
#   - if *value* consistent with
#         *assignment*:
#     - add {*var = value*} to *assignment*
#     - *inferences* = **Inference**(*assignment, csp*)
#     - if *inferences* ≠ *failure*:
#       - add *inferences* to
#                 *assignment*
#     - *result* = Backtrack(*assignment,
#             csp*)
#     - if *result* ≠ *failure*:
#       - return *result*
#     - *remove* {*var = value*} **and** *inferences* from *assignment*
# - return failure
#
# The Inference function runs the AC-3 algorithm as described. Its output
# is all the inferences that can be made through enforcing
# arc-consistency. Literally, these are the new assignments that can be
# deduced from the previous assignments and the structure of the constrain
# satisfaction problem.

# %% [markdown]
# There are additional ways to make the algorithm more efficient. So far,
# we selected an unassigned variable randomly. However, some choices are
# more likely to bring to a solution faster than others. This requires the
# use of heuristics. A heuristic is a rule of thumb, meaning that, more
# often than not, it will bring to a better result than following a naive
# approach, but it is not guaranteed to do so.
#
# **Minimum Remaining Values (MRV)** is one such heuristic. The idea here
# is that if a variable’s domain was constricted by inference, and now it
# has only one value left (or even if it’s two values), then by making
# this assignment we will reduce the number of backtracks we might need to
# do later. That is, we will have to make this assignment sooner or later,
# since it’s inferred from enforcing arc-consistency. If this assignment
# brings to failure, it is better to find out about it as soon as possible
# and not backtrack later.
#
# ![Minimum Remaining Values](https://cs50.harvard.edu/ai/2020/notes/3/mrv.png)
#
# For example, after having narrowed down the domains of variables given
# the current assignment, using the MRV heuristic, we will choose variable
# C next and assign the value Wednesday to it.
#
# The **Degree** heuristic relies on the degrees of variables, where a
# degree is how many arcs connect a variable to other variables. By
# choosing the variable with the highest degree, with one assignment, we
# constrain multiple other variables, speeding the algorithm’s process.
#
# ![Degree Heuristic](https://cs50.harvard.edu/ai/2020/notes/3/degree.png)
#
# For example, all the variables above have domains of the same size.
# Thus, we should pick a domain with the highest degree, which would be
# variable E.
#
# Both heuristics are not always applicable. For example, when multiple
# variables have the same least number of values in their domain, or when
# multiple variables have the same highest degree.
#
# Another way to make the algorithm more efficient is employing yet
# another heuristic when we select a value from the domain of a variable.
# Here, we would like to use the **Least Constraining Values** heuristic,
# where we select the value that will constrain the least other variables.
# The idea here is that, while in the degree heuristic we wanted to use
# the variable that is more likely to constrain other variables, here we
# want this variable to place the least constraints on other variables.
# That is, we want to locate what could be the largest potential source of
# trouble (the variable with the highest degree), and then render it the
# least troublesome that we can (assign the least constraining value to
# it).
#
# ![Least Constraining Value](https://cs50.harvard.edu/ai/2020/notes/3/leastconstrainingvalue.png)
#
# For example, let’s consider variable C. If we assign Tuesday to it, we
# will put a constraint on all of B, E, and F. However, if we choose
# Wednesday, we will put a constraint only on B and E. Therefore, it is
# probably better to go with Wednesday.
#
# To summarize, optimization problems can be formulated in multiple ways.
# Today we considered local search, linear programming, and constraint
# satisfaction.
